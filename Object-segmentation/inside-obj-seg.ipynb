# %%
# !pip install ultralytics

from IPython import display
display.clear_output()

import ultralytics
ultralytics.checks()
# Out:
# Ultralytics YOLOv8.2.34 🚀 Python-3.10.12 torch-2.3.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 30.2/201.2 GB disk)

# %%
from ultralytics import YOLO

from IPython.display import display, Image

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# large

model = YOLO("yolov8l-seg.pt")  # load a pretrained model (recommended for training)
# Out:
# ...
# 100%|██████████| 88.1M/88.1M [00:00<00:00, 396MB/s]

# %%
results = model.train(data="/content/drive/MyDrive/TFG/inside-obj-seg/train-dataset-yolo/data.yaml", epochs=50, project="/content/drive/MyDrive/TFG/inside-obj-seg/training-results-yolo/", name="train01", plots=True)
# Out:
# Ultralytics YOLOv8.2.34 🚀 Python-3.10.12 torch-2.3.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
01
