# %% [markdown]
# # **Kitchen Object Classification**

# %%
# Fundamental classes
import numpy as np
import pandas as pd
import tensorflow as tf
import os

# Image related
import cv2
from PIL import Image

#Performance Plot
from sklearn import metrics
from sklearn.metrics import f1_score, accuracy_score,confusion_matrix,classification_report
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# For the model and it's training
from sklearn.model_selection import train_test_split
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.models import Sequential, load_model, Model
from tensorflow.keras.layers import Conv2D, MaxPool2D, Dense, Flatten, Dropout, BatchNormalization, Input, Add
from tensorflow.keras.preprocessing.image import load_img, img_to_array

# Time
import time
import datetime

# %% [markdown]
# # Preprocessing

# %% [markdown]
# **Region extraction from images**

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os
import pandas as pd
import cv2
import numpy as np
from tensorflow.keras.preprocessing.image import img_to_array, load_img
from sklearn.model_selection import train_test_split

# Llegir el fitxer d'anotacions
annotations_path = '/content/drive/MyDrive/TFG/kitchen-obj-classification/_annotations_regions.csv'
annotations_df = pd.read_csv(annotations_path)

# Definir el camí de les imatges
IMAGES_PATH = '/content/drive/MyDrive/TFG/kitchen-obj-seg/train-dataset/images/'

# Funció per carregar i extreure les regions anotades per cada classe
def load_annotated_regions_for_class(annotations_df, class_name, images_path, target_size=(150, 150)):
    images = []
    labels = []
    class_df = annotations_df[annotations_df['class'] == class_name]
    for _, row in class_df.iterrows():
        img_path = os.path.join(images_path, row['filename'])
        image = load_img(img_path, color_mode='grayscale')
        image = img_to_array(image)
        x_min = int(row['xmin'])
        y_min = int(row['ymin'])
        x_max = int(row['xmax'])
        y_max = int(row['ymax'])
        region = image[y_min:y_max, x_min:x_max]
        region = cv2.resize(region, target_size)
        region = region / 255.0  # Normalitzar
        images.append(region)
        labels.append(row['labels'])
    return np.array(images), np.array(labels)

# Carregar les dades per cada classe
classes = ['sink', 'floor', 'cabinet', 'counter', 'tiles']
data = {}

for class_name in classes:
    x, y = load_annotated_regions_for_class(annotations_df, class_name, IMAGES_PATH)
    x_train, x_val, y_train, y_val = train_test_split(x, y, test_size=0.2, random_state=42)
    data[class_name] = (x_train, x_val, y_train, y_val)

# Mostrar un exemple de dades carregades
for class_name, (x_train, x_val, y_train, y_val) in data.items():
    print(f"Class: {class_name}, Train samples: {x_train.shape[0]}, Validation samples: {x_val.shape[0]}")
# Out:
# Class: sink, Train samples: 106, Validation samples: 27
# Class: floor, Train samples: 114, Validation samples: 29
# Class: cabinet, Train samples: 190, Validation samples: 48
# Class: counter, Train samples: 162, Validation samples: 41
# Class: tiles, Train samples: 182, Validation samples: 46

# %% [markdown]
# # Training

# %% [markdown]
# **Simple CNN**

# %% [markdown]
# Model

# %%
import tensorflow as tf
from tensorflow.keras import layers, models
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint

def create_simple_cnn(input_shape=(150, 150, 1)):
    model = models.Sequential([
        layers.Conv2D(32, (5, 5), activation='relu', input_shape=input_shape),
        layers.BatchNormalization(),
        layers.Conv2D(32, (5, 5), activation='relu'),
        layers.BatchNormalization(),
        layers.MaxPooling2D(pool_size=(2, 2)),
        layers.Dropout(rate=0.25),
        layers.Conv2D(64, (3, 3), activation='relu'),
        layers.BatchNormalization(),
        layers.Conv2D(64, (3, 3), activation='relu'),
        layers.BatchNormalization(),
        layers.MaxPooling2D(pool_size=(2, 2)),
        layers.Dropout(rate=0.25),
        layers.Flatten(),
        layers.Dense(256, activation='relu'),
        layers.Dropout(rate=0.5),
        layers.Dense(1, activation='sigmoid')
    ])

    model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])
    return model

create_simple_cnn().summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 146, 146, 32)      832
#
#  batch_normalization (Batch  (None, 146, 146, 32)      128
#  Normalization)
#
#  conv2d_1 (Conv2D)           (None, 142, 142, 32)      25632
#
#  batch_normalization_1 (Bat  (None, 142, 142, 32)      128
#  chNormalization)
#
#  max_pooling2d (MaxPooling2  (None, 71, 71, 32)        0
#  D)
#
#  dropout (Dropout)           (None, 71, 71, 32)        0
#
#  conv2d_2 (Conv2D)           (None, 69, 69, 64)        18496
#
#  batch_normalization_2 (Bat  (None, 69, 69, 64)        256
#  chNormalization)
#
#  conv2d_3 (Conv2D)           (None, 67, 67, 64)        36928
#
#  batch_normalization_3 (Bat  (None, 67, 67, 64)        256
#  chNormalization)
#
#  max_pooling2d_1 (MaxPoolin  (None, 33, 33, 64)        0
#  g2D)
#
#  dropout_1 (Dropout)         (None, 33, 33, 64)        0
#
#  flatten (Flatten)           (None, 69696)             0
#
#  dense (Dense)               (None, 256)               17842432
#
#  dropout_2 (Dropout)         (None, 256)               0
#
#  dense_1 (Dense)             (None, 1)                 257
#
# =================================================================
# Total params: 17925345 (68.38 MB)
# Trainable params: 17924961 (68.38 MB)
# Non-trainable params: 384 (1.50 KB)
# _________________________________________________________________

# %% [markdown]
# Training

# %%
# Train a simple CNN model for each class
trained_models_simple_cnn = {}

for class_name, (x_train, x_val, y_train, y_val) in data.items():
    print(f"Training simple CNN model for class: {class_name}")

    model = create_simple_cnn(input_shape=(150, 150, 1))

    # Define callbacks
    callbacks = [
        EarlyStopping(patience=10, restore_best_weights=True),
        ModelCheckpoint(f'/content/drive/MyDrive/TFG/kitchen-obj-classification/models/simple_cnn_model_{class_name}.h5', save_best_only=True)
    ]

    # Train the model
    history = model.fit(
        x_train, y_train,
        validation_data=(x_val, y_val),
        epochs=50,
        batch_size=16,
        callbacks=callbacks
    )

    trained_models_simple_cnn[class_name] = model

    print(f"Simple CNN model for class {class_name} trained and saved.")
# Out:
# Training simple CNN model for class: sink
# Epoch 1/50
# 7/7 [==============================] - ETA: 0s - loss: 21.5155 - accuracy: 0.4811
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 7/7 [==============================] - 14s 740ms/step - loss: 21.5155 - accuracy: 0.4811 - val_loss: 1.0130 - val_accuracy: 0.4815
# Epoch 2/50
# 7/7 [==============================] - 0s 73ms/step - loss: 9.1678 - accuracy: 0.6604 - val_loss: 4.4684 - val_accuracy: 0.4815
# Epoch 3/50
# 7/7 [==============================] - 0s 55ms/step - loss: 3.2074 - accuracy: 0.8019 - val_loss: 3.7786 - val_accuracy: 0.4815
# Epoch 4/50
# 7/7 [==============================] - 0s 54ms/step - loss: 4.1326 - accuracy: 0.8585 - val_loss: 5.6160 - val_accuracy: 0.4444
# Epoch 5/50
# 7/7 [==============================] - 0s 58ms/step - loss: 2.4855 - accuracy: 0.8491 - val_loss: 3.3039 - val_accuracy: 0.4815
# Epoch 6/50
# 7/7 [==============================] - 0s 64ms/step - loss: 2.0137 - accuracy: 0.8962 - val_loss: 3.1454 - val_accuracy: 0.4815
# Epoch 7/50
# 7/7 [==============================] - 0s 58ms/step - loss: 1.5509 - accuracy: 0.9151 - val_loss: 11.5360 - val_accuracy: 0.4815
# Epoch 8/50
# 7/7 [==============================] - 0s 56ms/step - loss: 1.0581 - accuracy: 0.8396 - val_loss: 3.0291 - val_accuracy: 0.4815
# Epoch 9/50
# 7/7 [==============================] - 0s 56ms/step - loss: 0.5711 - accuracy: 0.9623 - val_loss: 5.1596 - val_accuracy: 0.4815
# Epoch 10/50
# 7/7 [==============================] - 0s 55ms/step - loss: 0.5545 - accuracy: 0.9528 - val_loss: 6.0810 - val_accuracy: 0.4815
# Epoch 11/50
# 7/7 [==============================] - 0s 74ms/step - loss: 1.2213 - accuracy: 0.8868 - val_loss: 5.0159 - val_accuracy: 0.5185
# Simple CNN model for class sink trained and saved.
# Training simple CNN model for class: floor
# Epoch 1/50
# 8/8 [==============================] - 7s 438ms/step - loss: 14.3313 - accuracy: 0.6316 - val_loss: 3.2280 - val_accuracy: 0.5172
# Epoch 2/50
# 8/8 [==============================] - 0s 54ms/step - loss: 17.1114 - accuracy: 0.6491 - val_loss: 3.9011 - val_accuracy: 0.4828
# Epoch 3/50
# 8/8 [==============================] - 0s 53ms/step - loss: 15.1502 - accuracy: 0.7193 - val_loss: 4.7094 - val_accuracy: 0.5172
# Epoch 4/50
# 8/8 [==============================] - 0s 54ms/step - loss: 7.6766 - accuracy: 0.8070 - val_loss: 8.0283 - val_accuracy: 0.5172
# Epoch 5/50
# 8/8 [==============================] - 0s 54ms/step - loss: 9.5451 - accuracy: 0.7368 - val_loss: 11.5696 - val_accuracy: 0.5172
# Epoch 6/50
# 8/8 [==============================] - 0s 57ms/step - loss: 5.8924 - accuracy: 0.7982 - val_loss: 12.9733 - val_accuracy: 0.5172
# Epoch 7/50
# 8/8 [==============================] - 0s 61ms/step - loss: 6.4153 - accuracy: 0.8158 - val_loss: 6.0335 - val_accuracy: 0.5172
# Epoch 8/50
# 8/8 [==============================] - 0s 53ms/step - loss: 6.4943 - accuracy: 0.7895 - val_loss: 36.9802 - val_accuracy: 0.5172
# Epoch 9/50
# 8/8 [==============================] - 0s 53ms/step - loss: 2.8352 - accuracy: 0.8860 - val_loss: 39.7304 - val_accuracy: 0.5172
# Epoch 10/50
# 8/8 [==============================] - 0s 54ms/step - loss: 6.9860 - accuracy: 0.7982 - val_loss: 36.6842 - val_accuracy: 0.5172
# Epoch 11/50
# 8/8 [==============================] - 1s 68ms/step - loss: 4.1982 - accuracy: 0.8860 - val_loss: 32.6682 - val_accuracy: 0.5172
# Simple CNN model for class floor trained and saved.
# Training simple CNN model for class: cabinet
# Epoch 1/50
# 12/12 [==============================] - 8s 443ms/step - loss: 22.2736 - accuracy: 0.5053 - val_loss: 3.4758 - val_accuracy: 0.2708
# Epoch 2/50
# 12/12 [==============================] - 2s 153ms/step - loss: 8.9619 - accuracy: 0.6632 - val_loss: 0.8350 - val_accuracy: 0.6458
# Epoch 3/50
# 12/12 [==============================] - 1s 57ms/step - loss: 5.9309 - accuracy: 0.7000 - val_loss: 14.7666 - val_accuracy: 0.2708
# Epoch 4/50
# 12/12 [==============================] - 1s 63ms/step - loss: 3.1404 - accuracy: 0.7579 - val_loss: 9.8481 - val_accuracy: 0.2708
# Epoch 5/50
# 12/12 [==============================] - 1s 57ms/step - loss: 2.1124 - accuracy: 0.7947 - val_loss: 4.4524 - val_accuracy: 0.2708
# Epoch 6/50
# 12/12 [==============================] - 1s 62ms/step - loss: 1.8638 - accuracy: 0.7895 - val_loss: 9.2013 - val_accuracy: 0.2708
# Epoch 7/50
# 12/12 [==============================] - 1s 73ms/step - loss: 1.0736 - accuracy: 0.8526 - val_loss: 24.5301 - val_accuracy: 0.2708
# Epoch 8/50
# 12/12 [==============================] - 1s 57ms/step - loss: 1.0988 - accuracy: 0.8474 - val_loss: 57.7575 - val_accuracy: 0.2708
# Epoch 9/50
# 12/12 [==============================] - 1s 58ms/step - loss: 0.7611 - accuracy: 0.8684 - val_loss: 61.6355 - val_accuracy: 0.2708
# Epoch 10/50
# 12/12 [==============================] - 1s 62ms/step - loss: 0.5250 - accuracy: 0.8632 - val_loss: 50.6129 - val_accuracy: 0.2708
# Epoch 11/50
# 12/12 [==============================] - 1s 60ms/step - loss: 0.4467 - accuracy: 0.8842 - val_loss: 52.9348 - val_accuracy: 0.2708
# Epoch 12/50
# 12/12 [==============================] - 1s 74ms/step - loss: 0.5867 - accuracy: 0.8895 - val_loss: 52.1607 - val_accuracy: 0.2708
# Simple CNN model for class cabinet trained and saved.
# Training simple CNN model for class: counter
# Epoch 1/50
# 11/11 [==============================] - 5s 213ms/step - loss: 14.9157 - accuracy: 0.5432 - val_loss: 1.4061 - val_accuracy: 0.6585
# Epoch 2/50
# 11/11 [==============================] - 1s 57ms/step - loss: 14.8148 - accuracy: 0.6111 - val_loss: 2.0291 - val_accuracy: 0.3902
# Epoch 3/50
# 11/11 [==============================] - 2s 180ms/step - loss: 8.4840 - accuracy: 0.6420 - val_loss: 1.0427 - val_accuracy: 0.5854
# Epoch 4/50
# 11/11 [==============================] - 1s 61ms/step - loss: 6.1018 - accuracy: 0.7531 - val_loss: 3.2385 - val_accuracy: 0.6829
# Epoch 5/50
# 11/11 [==============================] - 1s 61ms/step - loss: 3.4311 - accuracy: 0.8086 - val_loss: 6.1767 - val_accuracy: 0.6829
# Epoch 6/50
# 11/11 [==============================] - 1s 59ms/step - loss: 1.5880 - accuracy: 0.8827 - val_loss: 10.7325 - val_accuracy: 0.6829
# Epoch 7/50
# 11/11 [==============================] - 1s 57ms/step - loss: 1.9458 - accuracy: 0.8765 - val_loss: 13.9312 - val_accuracy: 0.6829
# Epoch 8/50
# 11/11 [==============================] - 1s 62ms/step - loss: 1.2252 - accuracy: 0.9136 - val_loss: 4.3713 - val_accuracy: 0.6829
# Epoch 9/50
# 11/11 [==============================] - 1s 54ms/step - loss: 1.0804 - accuracy: 0.9074 - val_loss: 6.9454 - val_accuracy: 0.6829
# Epoch 10/50
# 11/11 [==============================] - 1s 56ms/step - loss: 0.4967 - accuracy: 0.9012 - val_loss: 7.1669 - val_accuracy: 0.6829
# Epoch 11/50
# 11/11 [==============================] - 1s 54ms/step - loss: 0.3983 - accuracy: 0.9444 - val_loss: 4.2498 - val_accuracy: 0.6829
# Epoch 12/50
# 11/11 [==============================] - 1s 54ms/step - loss: 0.1411 - accuracy: 0.9691 - val_loss: 2.7635 - val_accuracy: 0.6585
# Epoch 13/50
# 11/11 [==============================] - 1s 64ms/step - loss: 0.3285 - accuracy: 0.9444 - val_loss: 4.1987 - val_accuracy: 0.6585
# Simple CNN model for class counter trained and saved.
# Training simple CNN model for class: tiles
# Epoch 1/50
# 12/12 [==============================] - 7s 292ms/step - loss: 12.9201 - accuracy: 0.5495 - val_loss: 7.5119 - val_accuracy: 0.5652
# Epoch 2/50
# 12/12 [==============================] - 1s 55ms/step - loss: 13.5702 - accuracy: 0.6923 - val_loss: 13.8820 - val_accuracy: 0.5652
# Epoch 3/50
# 12/12 [==============================] - 2s 139ms/step - loss: 9.0093 - accuracy: 0.6484 - val_loss: 4.9440 - val_accuracy: 0.5652
# Epoch 4/50
# 12/12 [==============================] - 3s 293ms/step - loss: 9.6156 - accuracy: 0.7253 - val_loss: 1.6978 - val_accuracy: 0.3913
# Epoch 5/50
# 12/12 [==============================] - 1s 63ms/step - loss: 7.3928 - accuracy: 0.7692 - val_loss: 7.7475 - val_accuracy: 0.5652
# Epoch 6/50
# 12/12 [==============================] - 2s 177ms/step - loss: 5.2866 - accuracy: 0.7802 - val_loss: 1.4020 - val_accuracy: 0.4783
# Epoch 7/50
# 12/12 [==============================] - 1s 60ms/step - loss: 2.8631 - accuracy: 0.8077 - val_loss: 1.8524 - val_accuracy: 0.5217
# Epoch 8/50
# 12/12 [==============================] - 1s 62ms/step - loss: 2.6607 - accuracy: 0.8462 - val_loss: 5.5061 - val_accuracy: 0.5652
# Epoch 9/50
# 12/12 [==============================] - 2s 156ms/step - loss: 1.6408 - accuracy: 0.8956 - val_loss: 1.3781 - val_accuracy: 0.5000
# Epoch 10/50
# 12/12 [==============================] - 2s 197ms/step - loss: 1.2566 - accuracy: 0.8901 - val_loss: 1.3267 - val_accuracy: 0.5870
# Epoch 11/50
# 12/12 [==============================] - 1s 54ms/step - loss: 1.9520 - accuracy: 0.8736 - val_loss: 19.6022 - val_accuracy: 0.5652
# Epoch 12/50
# 12/12 [==============================] - 1s 55ms/step - loss: 1.9045 - accuracy: 0.9231 - val_loss: 18.8266 - val_accuracy: 0.5652
# Epoch 13/50
# 12/12 [==============================] - 1s 58ms/step - loss: 1.6818 - accuracy: 0.9011 - val_loss: 6.8469 - val_accuracy: 0.5652
# Epoch 14/50
# 12/12 [==============================] - 1s 58ms/step - loss: 1.9311 - accuracy: 0.8846 - val_loss: 6.8282 - val_accuracy: 0.5652
# Epoch 15/50
# 12/12 [==============================] - 1s 59ms/step - loss: 1.2366 - accuracy: 0.9341 - val_loss: 8.0532 - val_accuracy: 0.5652
# Epoch 16/50
# 12/12 [==============================] - 1s 58ms/step - loss: 1.7463 - accuracy: 0.9231 - val_loss: 8.8883 - val_accuracy: 0.5652
# Epoch 17/50
# 12/12 [==============================] - 1s 58ms/step - loss: 1.0051 - accuracy: 0.9451 - val_loss: 1.9120 - val_accuracy: 0.3913
# Epoch 18/50
# 12/12 [==============================] - 1s 58ms/step - loss: 0.2470 - accuracy: 0.9780 - val_loss: 22.2960 - val_accuracy: 0.4348
# Epoch 19/50
# 12/12 [==============================] - 1s 58ms/step - loss: 1.5414 - accuracy: 0.9396 - val_loss: 10.0009 - val_accuracy: 0.5652
# Epoch 20/50
# 12/12 [==============================] - 1s 79ms/step - loss: 0.6106 - accuracy: 0.9670 - val_loss: 3.1010 - val_accuracy: 0.5000
# Simple CNN model for class tiles trained and saved.

# %% [markdown]
# **VGG**

# %% [markdown]
# Model

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout

def create_vgg_model(input_shape=(150, 150, 1)):
    model = Sequential([
        Conv2D(64, (3, 3), activation='relu', padding='same', input_shape=input_shape),
        Conv2D(64, (3, 3), activation='relu', padding='same'),
        MaxPooling2D(pool_size=(2, 2)),

        Conv2D(128, (3, 3), activation='relu', padding='same'),
        Conv2D(128, (3, 3), activation='relu', padding='same'),
        MaxPooling2D(pool_size=(2, 2)),

        Conv2D(256, (3, 3), activation='relu', padding='same'),
        Conv2D(256, (3, 3), activation='relu', padding='same'),
        MaxPooling2D(pool_size=(2, 2)),

        Flatten(),
        Dense(512, activation='relu'),
        Dropout(0.5),
        Dense(512, activation='relu'),
        Dropout(0.5),
        Dense(1, activation='sigmoid')
    ])

    model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])
    return model

create_vgg_model().summary()
# Out:
# Model: "sequential_6"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_24 (Conv2D)          (None, 150, 150, 64)      640
#
#  conv2d_25 (Conv2D)          (None, 150, 150, 64)      36928
#
#  max_pooling2d_12 (MaxPooli  (None, 75, 75, 64)        0
#  ng2D)
#
#  conv2d_26 (Conv2D)          (None, 75, 75, 128)       73856
#
#  conv2d_27 (Conv2D)          (None, 75, 75, 128)       147584
#
#  max_pooling2d_13 (MaxPooli  (None, 37, 37, 128)       0
#  ng2D)
#
#  conv2d_28 (Conv2D)          (None, 37, 37, 256)       295168
#
#  conv2d_29 (Conv2D)          (None, 37, 37, 256)       590080
#
#  max_pooling2d_14 (MaxPooli  (None, 18, 18, 256)       0
#  ng2D)
#
#  flatten_6 (Flatten)         (None, 82944)             0
#
#  dense_12 (Dense)            (None, 512)               42467840
#
#  dropout_18 (Dropout)        (None, 512)               0
#
#  dense_13 (Dense)            (None, 512)               262656
#
#  dropout_19 (Dropout)        (None, 512)               0
#
#  dense_14 (Dense)            (None, 1)                 513
#
# =================================================================
# Total params: 43875265 (167.37 MB)
# Trainable params: 43875265 (167.37 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %% [markdown]
# Training

# %%
# Train a VGG-like model for each class
trained_models_vgg = {}

for class_name, (x_train, x_val, y_train, y_val) in data.items():
    print(f"Training VGG model for class: {class_name}")

    model = create_vgg_model(input_shape=(150, 150, 1))

    # Define callbacks
    callbacks = [
        EarlyStopping(patience=15, restore_best_weights=True),
        ModelCheckpoint(f'/content/drive/MyDrive/TFG/kitchen-obj-classification/models/vgg_model_{class_name}.h5', save_best_only=True)
    ]

    # Train the model
    history = model.fit(
        x_train, y_train,
        validation_data=(x_val, y_val),
        epochs=50,
        batch_size=16,
        callbacks=callbacks
    )

    trained_models_vgg[class_name] = model

    print(f"VGG model for class {class_name} trained and saved.")
# Out:
# Training VGG model for class: sink
# Epoch 1/50
# 7/7 [==============================] - 32s 4s/step - loss: 0.8521 - accuracy: 0.5377 - val_loss: 0.6943 - val_accuracy: 0.4815
# Epoch 2/50
# 7/7 [==============================] - 1s 93ms/step - loss: 0.6943 - accuracy: 0.5189 - val_loss: 0.6944 - val_accuracy: 0.4815
# Epoch 3/50
# 7/7 [==============================] - 5s 751ms/step - loss: 0.7006 - accuracy: 0.4906 - val_loss: 0.6925 - val_accuracy: 0.5185
# Epoch 4/50
# 7/7 [==============================] - 5s 833ms/step - loss: 0.6911 - accuracy: 0.5472 - val_loss: 0.6924 - val_accuracy: 0.5185
# Epoch 5/50
# 7/7 [==============================] - 1s 90ms/step - loss: 0.6949 - accuracy: 0.4906 - val_loss: 0.6932 - val_accuracy: 0.5185
# Epoch 6/50
# 7/7 [==============================] - 1s 86ms/step - loss: 0.6943 - accuracy: 0.5283 - val_loss: 0.6928 - val_accuracy: 0.5185
# Epoch 7/50
# 7/7 [==============================] - 1s 86ms/step - loss: 0.6940 - accuracy: 0.5189 - val_loss: 0.6925 - val_accuracy: 0.5185
# Epoch 8/50
# 7/7 [==============================] - 1s 87ms/step - loss: 0.6930 - accuracy: 0.5283 - val_loss: 0.6925 - val_accuracy: 0.5185
# Epoch 9/50
# 7/7 [==============================] - 1s 87ms/step - loss: 0.6898 - accuracy: 0.5283 - val_loss: 0.6925 - val_accuracy: 0.5185
# Epoch 10/50
# 7/7 [==============================] - 1s 83ms/step - loss: 0.6928 - accuracy: 0.5283 - val_loss: 0.6925 - val_accuracy: 0.5185
# Epoch 11/50
# 7/7 [==============================] - 1s 83ms/step - loss: 0.6914 - accuracy: 0.5283 - val_loss: 0.6925 - val_accuracy: 0.5185
# Epoch 12/50
# 7/7 [==============================] - 1s 89ms/step - loss: 0.6921 - accuracy: 0.5283 - val_loss: 0.6925 - val_accuracy: 0.5185
# Epoch 13/50
# 7/7 [==============================] - 1s 90ms/step - loss: 0.6918 - accuracy: 0.5283 - val_loss: 0.6925 - val_accuracy: 0.5185
# Epoch 14/50
# 7/7 [==============================] - 1s 87ms/step - loss: 0.6921 - accuracy: 0.5283 - val_loss: 0.6926 - val_accuracy: 0.5185
# Epoch 15/50
# 7/7 [==============================] - 1s 90ms/step - loss: 0.6907 - accuracy: 0.5283 - val_loss: 0.6927 - val_accuracy: 0.5185
# Epoch 16/50
# 7/7 [==============================] - 1s 88ms/step - loss: 0.6927 - accuracy: 0.5283 - val_loss: 0.6927 - val_accuracy: 0.5185
# Epoch 17/50
# 7/7 [==============================] - 1s 88ms/step - loss: 0.6911 - accuracy: 0.5283 - val_loss: 0.6927 - val_accuracy: 0.5185
# Epoch 18/50
# 7/7 [==============================] - 1s 81ms/step - loss: 0.6892 - accuracy: 0.5283 - val_loss: 0.6927 - val_accuracy: 0.5185
# Epoch 19/50
# 7/7 [==============================] - 1s 130ms/step - loss: 0.6918 - accuracy: 0.5283 - val_loss: 0.6928 - val_accuracy: 0.5185
# VGG model for class sink trained and saved.
# Training VGG model for class: floor
# Epoch 1/50
# 8/8 [==============================] - 21s 2s/step - loss: 0.7108 - accuracy: 0.5702 - val_loss: 0.6928 - val_accuracy: 0.5172
# Epoch 2/50
# 8/8 [==============================] - 4s 611ms/step - loss: 0.7338 - accuracy: 0.5789 - val_loss: 0.6927 - val_accuracy: 0.5172
# Epoch 3/50
# 8/8 [==============================] - 1s 81ms/step - loss: 0.7004 - accuracy: 0.4737 - val_loss: 0.6928 - val_accuracy: 0.5172
# Epoch 4/50
# 8/8 [==============================] - 1s 79ms/step - loss: 0.6896 - accuracy: 0.5702 - val_loss: 0.7115 - val_accuracy: 0.5172
# Epoch 5/50
# 8/8 [==============================] - 1s 81ms/step - loss: 0.7148 - accuracy: 0.5175 - val_loss: 0.6935 - val_accuracy: 0.5172
# Epoch 6/50
# 8/8 [==============================] - 1s 81ms/step - loss: 0.6834 - accuracy: 0.6053 - val_loss: 0.6930 - val_accuracy: 0.5172
# Epoch 7/50
# 8/8 [==============================] - 1s 81ms/step - loss: 0.6826 - accuracy: 0.6053 - val_loss: 0.6934 - val_accuracy: 0.5172
# Epoch 8/50
# 8/8 [==============================] - 1s 84ms/step - loss: 0.6799 - accuracy: 0.6053 - val_loss: 0.6967 - val_accuracy: 0.5172
# Epoch 9/50
# 8/8 [==============================] - 1s 85ms/step - loss: 0.6780 - accuracy: 0.6053 - val_loss: 0.7038 - val_accuracy: 0.5172
# Epoch 10/50
# 8/8 [==============================] - 1s 80ms/step - loss: 0.6834 - accuracy: 0.6053 - val_loss: 0.7220 - val_accuracy: 0.5172
# Epoch 11/50
# 8/8 [==============================] - 1s 79ms/step - loss: 0.6796 - accuracy: 0.6053 - val_loss: 0.6964 - val_accuracy: 0.5172
# Epoch 12/50
# 8/8 [==============================] - 1s 93ms/step - loss: 0.6744 - accuracy: 0.6053 - val_loss: 0.6951 - val_accuracy: 0.5172
# Epoch 13/50
# 8/8 [==============================] - 1s 83ms/step - loss: 0.6767 - accuracy: 0.6053 - val_loss: 0.6955 - val_accuracy: 0.5172
# Epoch 14/50
# 8/8 [==============================] - 1s 77ms/step - loss: 0.6759 - accuracy: 0.6053 - val_loss: 0.6964 - val_accuracy: 0.5172
# Epoch 15/50
# 8/8 [==============================] - 1s 79ms/step - loss: 0.6737 - accuracy: 0.6053 - val_loss: 0.6981 - val_accuracy: 0.5172
# Epoch 16/50
# 8/8 [==============================] - 1s 82ms/step - loss: 0.6733 - accuracy: 0.6053 - val_loss: 0.7028 - val_accuracy: 0.5172
# Epoch 17/50
# 8/8 [==============================] - 1s 111ms/step - loss: 0.6750 - accuracy: 0.6053 - val_loss: 0.7162 - val_accuracy: 0.5172
# VGG model for class floor trained and saved.
# Training VGG model for class: cabinet
# Epoch 1/50
# 12/12 [==============================] - 22s 2s/step - loss: 0.6987 - accuracy: 0.5789 - val_loss: 0.6013 - val_accuracy: 0.7292
# Epoch 2/50
# 12/12 [==============================] - 7s 647ms/step - loss: 0.6529 - accuracy: 0.6421 - val_loss: 0.5840 - val_accuracy: 0.7292
# Epoch 3/50
# 12/12 [==============================] - 1s 89ms/step - loss: 0.6648 - accuracy: 0.6421 - val_loss: 0.6019 - val_accuracy: 0.7292
# Epoch 4/50
# 12/12 [==============================] - 1s 82ms/step - loss: 0.6658 - accuracy: 0.6474 - val_loss: 0.6337 - val_accuracy: 0.7292
# Epoch 5/50
# 12/12 [==============================] - 1s 82ms/step - loss: 0.6517 - accuracy: 0.6421 - val_loss: 0.5923 - val_accuracy: 0.7292
# Epoch 6/50
# 12/12 [==============================] - 1s 82ms/step - loss: 0.6453 - accuracy: 0.6421 - val_loss: 0.5853 - val_accuracy: 0.7292
# Epoch 7/50
# 12/12 [==============================] - 1s 82ms/step - loss: 0.6684 - accuracy: 0.6421 - val_loss: 0.6119 - val_accuracy: 0.7292
# Epoch 8/50
# 12/12 [==============================] - 1s 82ms/step - loss: 0.6601 - accuracy: 0.6474 - val_loss: 0.6051 - val_accuracy: 0.7292
# Epoch 9/50
# 12/12 [==============================] - 1s 82ms/step - loss: 0.6657 - accuracy: 0.6421 - val_loss: 0.6304 - val_accuracy: 0.7292
# Epoch 10/50
# 12/12 [==============================] - 1s 82ms/step - loss: 0.6660 - accuracy: 0.6421 - val_loss: 0.6238 - val_accuracy: 0.7292
# Epoch 11/50
# 12/12 [==============================] - 1s 83ms/step - loss: 0.6621 - accuracy: 0.6421 - val_loss: 0.5999 - val_accuracy: 0.7292
# Epoch 12/50
# 12/12 [==============================] - 1s 83ms/step - loss: 0.6570 - accuracy: 0.6421 - val_loss: 0.6154 - val_accuracy: 0.7292
# Epoch 13/50
# 12/12 [==============================] - 1s 85ms/step - loss: 0.6617 - accuracy: 0.6421 - val_loss: 0.6005 - val_accuracy: 0.7292
# Epoch 14/50
# 12/12 [==============================] - 1s 88ms/step - loss: 0.6593 - accuracy: 0.6421 - val_loss: 0.6116 - val_accuracy: 0.7292
# Epoch 15/50
# 12/12 [==============================] - 1s 87ms/step - loss: 0.6587 - accuracy: 0.6421 - val_loss: 0.6309 - val_accuracy: 0.7292
# Epoch 16/50
# 12/12 [==============================] - 1s 90ms/step - loss: 0.6618 - accuracy: 0.6421 - val_loss: 0.6068 - val_accuracy: 0.7292
# Epoch 17/50
# 12/12 [==============================] - 1s 121ms/step - loss: 0.6526 - accuracy: 0.6421 - val_loss: 0.6066 - val_accuracy: 0.7292
# VGG model for class cabinet trained and saved.
# Training VGG model for class: counter
# Epoch 1/50
# 11/11 [==============================] - 12s 1s/step - loss: 0.6873 - accuracy: 0.6358 - val_loss: 0.6531 - val_accuracy: 0.6829
# Epoch 2/50
# 11/11 [==============================] - 1s 81ms/step - loss: 0.6880 - accuracy: 0.6173 - val_loss: 0.6770 - val_accuracy: 0.6829
# Epoch 3/50
# 11/11 [==============================] - 4s 352ms/step - loss: 0.6802 - accuracy: 0.6235 - val_loss: 0.6395 - val_accuracy: 0.6829
# Epoch 4/50
# 11/11 [==============================] - 5s 450ms/step - loss: 0.6726 - accuracy: 0.6235 - val_loss: 0.6336 - val_accuracy: 0.6829
# Epoch 5/50
# 11/11 [==============================] - 1s 86ms/step - loss: 0.6690 - accuracy: 0.6235 - val_loss: 0.6573 - val_accuracy: 0.6829
# Epoch 6/50
# 11/11 [==============================] - 1s 79ms/step - loss: 0.6744 - accuracy: 0.6235 - val_loss: 0.6594 - val_accuracy: 0.6829
# Epoch 7/50
# 11/11 [==============================] - 1s 79ms/step - loss: 0.6735 - accuracy: 0.6235 - val_loss: 0.6418 - val_accuracy: 0.6829
# Epoch 8/50
# 11/11 [==============================] - 7s 662ms/step - loss: 0.6705 - accuracy: 0.6235 - val_loss: 0.6182 - val_accuracy: 0.6829
# Epoch 9/50
# 11/11 [==============================] - 1s 80ms/step - loss: 0.6689 - accuracy: 0.6235 - val_loss: 0.6330 - val_accuracy: 0.6829
# Epoch 10/50
# 11/11 [==============================] - 1s 80ms/step - loss: 0.6701 - accuracy: 0.6235 - val_loss: 0.6531 - val_accuracy: 0.6829
# Epoch 11/50
# 11/11 [==============================] - 1s 83ms/step - loss: 0.6585 - accuracy: 0.6235 - val_loss: 1.6794 - val_accuracy: 0.6829
# Epoch 12/50
# 11/11 [==============================] - 1s 81ms/step - loss: 0.6950 - accuracy: 0.6173 - val_loss: 0.6612 - val_accuracy: 0.6829
# Epoch 13/50
# 11/11 [==============================] - 1s 81ms/step - loss: 0.6734 - accuracy: 0.6173 - val_loss: 0.6546 - val_accuracy: 0.6829
# Epoch 14/50
# 11/11 [==============================] - 1s 84ms/step - loss: 0.6656 - accuracy: 0.6235 - val_loss: 0.6413 - val_accuracy: 0.6829
# Epoch 15/50
# 11/11 [==============================] - 1s 79ms/step - loss: 0.6658 - accuracy: 0.6235 - val_loss: 0.6349 - val_accuracy: 0.6829
# Epoch 16/50
# 11/11 [==============================] - 1s 82ms/step - loss: 0.6622 - accuracy: 0.6235 - val_loss: 0.6236 - val_accuracy: 0.6829
# Epoch 17/50
# 11/11 [==============================] - 4s 385ms/step - loss: 0.6628 - accuracy: 0.6235 - val_loss: 0.6049 - val_accuracy: 0.6829
# Epoch 18/50
# 11/11 [==============================] - 1s 80ms/step - loss: 0.6558 - accuracy: 0.6235 - val_loss: 0.6061 - val_accuracy: 0.6829
# Epoch 19/50
# 11/11 [==============================] - 1s 78ms/step - loss: 0.6360 - accuracy: 0.6481 - val_loss: 0.6419 - val_accuracy: 0.6829
# Epoch 20/50
# 11/11 [==============================] - 1s 77ms/step - loss: 0.6530 - accuracy: 0.6296 - val_loss: 0.6103 - val_accuracy: 0.6829
# Epoch 21/50
# 11/11 [==============================] - 1s 80ms/step - loss: 0.6621 - accuracy: 0.6420 - val_loss: 0.6417 - val_accuracy: 0.6829
# Epoch 22/50
# 11/11 [==============================] - 1s 80ms/step - loss: 0.6763 - accuracy: 0.6235 - val_loss: 0.6422 - val_accuracy: 0.6829
# Epoch 23/50
# 11/11 [==============================] - 1s 82ms/step - loss: 0.6696 - accuracy: 0.6235 - val_loss: 0.6465 - val_accuracy: 0.6829
# Epoch 24/50
# 11/11 [==============================] - 1s 81ms/step - loss: 0.6671 - accuracy: 0.6235 - val_loss: 0.6440 - val_accuracy: 0.6829
# Epoch 25/50
# 11/11 [==============================] - 1s 82ms/step - loss: 0.6671 - accuracy: 0.6235 - val_loss: 0.6449 - val_accuracy: 0.6829
# Epoch 26/50
# 11/11 [==============================] - 1s 94ms/step - loss: 0.6681 - accuracy: 0.6235 - val_loss: 0.6404 - val_accuracy: 0.6829
# Epoch 27/50
# 11/11 [==============================] - 1s 79ms/step - loss: 0.6653 - accuracy: 0.6235 - val_loss: 0.6360 - val_accuracy: 0.6829
# Epoch 28/50
# 11/11 [==============================] - 1s 78ms/step - loss: 0.6609 - accuracy: 0.6235 - val_loss: 0.6323 - val_accuracy: 0.6829
# Epoch 29/50
# 11/11 [==============================] - 1s 81ms/step - loss: 0.6623 - accuracy: 0.6235 - val_loss: 0.6298 - val_accuracy: 0.6829
# Epoch 30/50
# 11/11 [==============================] - 1s 81ms/step - loss: 0.6621 - accuracy: 0.6235 - val_loss: 0.6300 - val_accuracy: 0.6829
# Epoch 31/50
# 11/11 [==============================] - 1s 80ms/step - loss: 0.6639 - accuracy: 0.6235 - val_loss: 0.6295 - val_accuracy: 0.6829
# Epoch 32/50
# 11/11 [==============================] - 1s 105ms/step - loss: 0.6623 - accuracy: 0.6235 - val_loss: 0.6294 - val_accuracy: 0.6829
# VGG model for class counter trained and saved.
# Training VGG model for class: tiles
# Epoch 1/50
# 12/12 [==============================] - 22s 2s/step - loss: 0.9844 - accuracy: 0.5604 - val_loss: 0.6912 - val_accuracy: 0.5652
# Epoch 2/50
# 12/12 [==============================] - 5s 426ms/step - loss: 0.6957 - accuracy: 0.6154 - val_loss: 0.6877 - val_accuracy: 0.5652
# Epoch 3/50
# 12/12 [==============================] - 6s 525ms/step - loss: 0.6830 - accuracy: 0.5934 - val_loss: 0.6861 - val_accuracy: 0.5652
# Epoch 4/50
# 12/12 [==============================] - 1s 94ms/step - loss: 0.6838 - accuracy: 0.5989 - val_loss: 0.6863 - val_accuracy: 0.5652
# Epoch 5/50
# 12/12 [==============================] - 3s 290ms/step - loss: 0.6743 - accuracy: 0.5989 - val_loss: 0.6855 - val_accuracy: 0.5652
# Epoch 6/50
# 12/12 [==============================] - 1s 85ms/step - loss: 0.6751 - accuracy: 0.5989 - val_loss: 0.6867 - val_accuracy: 0.5652
# Epoch 7/50
# 12/12 [==============================] - 1s 80ms/step - loss: 0.6744 - accuracy: 0.5989 - val_loss: 0.6873 - val_accuracy: 0.5652
# Epoch 8/50
# 12/12 [==============================] - 7s 672ms/step - loss: 0.6791 - accuracy: 0.5989 - val_loss: 0.6852 - val_accuracy: 0.5652
# Epoch 9/50
# 12/12 [==============================] - 1s 88ms/step - loss: 0.6714 - accuracy: 0.5989 - val_loss: 0.6943 - val_accuracy: 0.5652
# Epoch 10/50
# 12/12 [==============================] - 1s 80ms/step - loss: 0.6726 - accuracy: 0.5989 - val_loss: 0.6867 - val_accuracy: 0.5652
# Epoch 11/50
# 12/12 [==============================] - 1s 81ms/step - loss: 0.6736 - accuracy: 0.5989 - val_loss: 0.6864 - val_accuracy: 0.5652
# Epoch 12/50
# 12/12 [==============================] - 7s 641ms/step - loss: 0.6748 - accuracy: 0.5989 - val_loss: 0.6847 - val_accuracy: 0.5652
# Epoch 13/50
# 12/12 [==============================] - 1s 84ms/step - loss: 0.6689 - accuracy: 0.5989 - val_loss: 0.6868 - val_accuracy: 0.5652
# Epoch 14/50
# 12/12 [==============================] - 1s 84ms/step - loss: 0.6813 - accuracy: 0.5934 - val_loss: 0.6865 - val_accuracy: 0.5652
# Epoch 15/50
# 12/12 [==============================] - 1s 84ms/step - loss: 0.6852 - accuracy: 0.5989 - val_loss: 0.6872 - val_accuracy: 0.5652
# Epoch 16/50
# 12/12 [==============================] - 7s 649ms/step - loss: 0.6780 - accuracy: 0.5989 - val_loss: 0.6844 - val_accuracy: 0.5652
# Epoch 17/50
# 12/12 [==============================] - 1s 83ms/step - loss: 0.6733 - accuracy: 0.5989 - val_loss: 0.6871 - val_accuracy: 0.5652
# Epoch 18/50
# 12/12 [==============================] - 1s 80ms/step - loss: 0.6683 - accuracy: 0.5989 - val_loss: 0.7009 - val_accuracy: 0.5652
# Epoch 19/50
# 12/12 [==============================] - 4s 320ms/step - loss: 0.6437 - accuracy: 0.6209 - val_loss: 0.6828 - val_accuracy: 0.5652
# Epoch 20/50
# 12/12 [==============================] - 1s 88ms/step - loss: 0.6444 - accuracy: 0.6044 - val_loss: 0.6862 - val_accuracy: 0.5435
# Epoch 21/50
# 12/12 [==============================] - 4s 362ms/step - loss: 0.5926 - accuracy: 0.6484 - val_loss: 0.6774 - val_accuracy: 0.5870
# Epoch 22/50
# 12/12 [==============================] - 4s 365ms/step - loss: 0.6184 - accuracy: 0.6484 - val_loss: 0.6723 - val_accuracy: 0.5870
# Epoch 23/50
# 12/12 [==============================] - 1s 84ms/step - loss: 0.5977 - accuracy: 0.6429 - val_loss: 0.8257 - val_accuracy: 0.5652
# Epoch 24/50
# 12/12 [==============================] - 5s 421ms/step - loss: 0.7163 - accuracy: 0.6484 - val_loss: 0.6711 - val_accuracy: 0.5652
# Epoch 25/50
# 12/12 [==============================] - 1s 86ms/step - loss: 0.6440 - accuracy: 0.6154 - val_loss: 0.7941 - val_accuracy: 0.5652
# Epoch 26/50
# 12/12 [==============================] - 1s 82ms/step - loss: 1.7619 - accuracy: 0.6099 - val_loss: 0.6809 - val_accuracy: 0.5870
# Epoch 27/50
# 12/12 [==============================] - 1s 80ms/step - loss: 0.7025 - accuracy: 0.5659 - val_loss: 0.6748 - val_accuracy: 0.5870
# Epoch 28/50
# 12/12 [==============================] - 1s 80ms/step - loss: 0.6789 - accuracy: 0.6374 - val_loss: 1.1646 - val_accuracy: 0.5435
# Epoch 29/50
# 12/12 [==============================] - 1s 81ms/step - loss: 0.5935 - accuracy: 0.6593 - val_loss: 0.9287 - val_accuracy: 0.6087
# Epoch 30/50
# 12/12 [==============================] - 1s 80ms/step - loss: 0.6518 - accuracy: 0.6648 - val_loss: 0.6958 - val_accuracy: 0.5652
# Epoch 31/50
# 12/12 [==============================] - 1s 81ms/step - loss: 0.5629 - accuracy: 0.6703 - val_loss: 0.8937 - val_accuracy: 0.6304
# Epoch 32/50
# 12/12 [==============================] - 1s 80ms/step - loss: 0.6933 - accuracy: 0.6593 - val_loss: 0.6758 - val_accuracy: 0.5652
# Epoch 33/50
# 12/12 [==============================] - 8s 756ms/step - loss: 0.6114 - accuracy: 0.6429 - val_loss: 0.6688 - val_accuracy: 0.5870
# Epoch 34/50
# 12/12 [==============================] - 6s 534ms/step - loss: 0.5988 - accuracy: 0.6429 - val_loss: 0.6636 - val_accuracy: 0.5870
# Epoch 35/50
# 12/12 [==============================] - 1s 82ms/step - loss: 0.5946 - accuracy: 0.6593 - val_loss: 1.0638 - val_accuracy: 0.5870
# Epoch 36/50
# 12/12 [==============================] - 1s 78ms/step - loss: 0.6066 - accuracy: 0.6099 - val_loss: 0.8154 - val_accuracy: 0.5652
# Epoch 37/50
# 12/12 [==============================] - 1s 81ms/step - loss: 0.5361 - accuracy: 0.6868 - val_loss: 1.0470 - val_accuracy: 0.5870
# Epoch 38/50
# 12/12 [==============================] - 1s 82ms/step - loss: 0.5298 - accuracy: 0.6868 - val_loss: 1.1131 - val_accuracy: 0.6087
# Epoch 39/50
# 12/12 [==============================] - 1s 80ms/step - loss: 0.5203 - accuracy: 0.6868 - val_loss: 1.3568 - val_accuracy: 0.6304
# Epoch 40/50
# 12/12 [==============================] - 1s 83ms/step - loss: 0.5529 - accuracy: 0.6429 - val_loss: 2.6838 - val_accuracy: 0.5870
# Epoch 41/50
# 12/12 [==============================] - 1s 81ms/step - loss: 0.5663 - accuracy: 0.6813 - val_loss: 0.9327 - val_accuracy: 0.5870
# Epoch 42/50
# 12/12 [==============================] - 1s 80ms/step - loss: 0.7212 - accuracy: 0.6538 - val_loss: 0.6818 - val_accuracy: 0.5870
# Epoch 43/50
# 12/12 [==============================] - 1s 81ms/step - loss: 0.7110 - accuracy: 0.5989 - val_loss: 0.6874 - val_accuracy: 0.5652
# Epoch 44/50
# 12/12 [==============================] - 1s 79ms/step - loss: 0.6661 - accuracy: 0.5989 - val_loss: 0.6860 - val_accuracy: 0.5652
# Epoch 45/50
# 12/12 [==============================] - 1s 81ms/step - loss: 0.6613 - accuracy: 0.6044 - val_loss: 0.6860 - val_accuracy: 0.5652
# Epoch 46/50
# 12/12 [==============================] - 1s 81ms/step - loss: 0.6524 - accuracy: 0.6044 - val_loss: 0.6855 - val_accuracy: 0.5652
# Epoch 47/50
# 12/12 [==============================] - 1s 82ms/step - loss: 0.6396 - accuracy: 0.6264 - val_loss: 0.6849 - val_accuracy: 0.5435
# Epoch 48/50
# 12/12 [==============================] - 1s 80ms/step - loss: 0.5929 - accuracy: 0.6429 - val_loss: 0.7366 - val_accuracy: 0.5435
# Epoch 49/50
# 12/12 [==============================] - 1s 105ms/step - loss: 0.5849 - accuracy: 0.6648 - val_loss: 0.7840 - val_accuracy: 0.5435
# VGG model for class tiles trained and saved.

# %% [markdown]
# **ResNet**

# %% [markdown]
# Model

# %%
from tensorflow.keras.layers import Input, Add, Conv2D, MaxPooling2D, Flatten, Dense, Dropout
from tensorflow.keras.models import Model

def resnet_block(input_tensor, filters, kernel_size=3):
    x = Conv2D(filters, (kernel_size, kernel_size), padding='same', activation='relu')(input_tensor)
    x = Conv2D(filters, (kernel_size, kernel_size), padding='same')(x)
    x = Add()([x, input_tensor])
    return x

def create_resnet_model(input_shape=(150, 150, 1)):
    inputs = Input(shape=input_shape)
    x = Conv2D(64, (3, 3), activation='relu', padding='same')(inputs)
    x = resnet_block(x, 64)
    x = MaxPooling2D(pool_size=(2, 2))(x)

    x = Conv2D(128, (3, 3), activation='relu', padding='same')(x)
    x = resnet_block(x, 128)
    x = MaxPooling2D(pool_size=(2, 2))(x)

    x = Conv2D(256, (3, 3), activation='relu', padding='same')(x)
    x = resnet_block(x, 256)
    x = MaxPooling2D(pool_size=(2, 2))(x)

    x = Flatten()(x)
    x = Dense(512, activation='relu')(x)
    x = Dropout(0.5)(x)
    outputs = Dense(1, activation='sigmoid')(x)

    model = Model(inputs, outputs)
    model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])
    return model

create_resnet_model().summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_1 (InputLayer)        [(None, 150, 150, 1)]        0         []
#
#  conv2d_60 (Conv2D)          (None, 150, 150, 64)         640       ['input_1[0][0]']
#
#  conv2d_61 (Conv2D)          (None, 150, 150, 64)         36928     ['conv2d_60[0][0]']
#
#  conv2d_62 (Conv2D)          (None, 150, 150, 64)         36928     ['conv2d_61[0][0]']
#
#  add (Add)                   (None, 150, 150, 64)         0         ['conv2d_62[0][0]',
#                                                                      'conv2d_60[0][0]']
#
#  max_pooling2d_30 (MaxPooli  (None, 75, 75, 64)           0         ['add[0][0]']
#  ng2D)
#
#  conv2d_63 (Conv2D)          (None, 75, 75, 128)          73856     ['max_pooling2d_30[0][0]']
#
#  conv2d_64 (Conv2D)          (None, 75, 75, 128)          147584    ['conv2d_63[0][0]']
#
#  conv2d_65 (Conv2D)          (None, 75, 75, 128)          147584    ['conv2d_64[0][0]']
#
#  add_1 (Add)                 (None, 75, 75, 128)          0         ['conv2d_65[0][0]',
#                                                                      'conv2d_63[0][0]']
#
#  max_pooling2d_31 (MaxPooli  (None, 37, 37, 128)          0         ['add_1[0][0]']
#  ng2D)
#
#  conv2d_66 (Conv2D)          (None, 37, 37, 256)          295168    ['max_pooling2d_31[0][0]']
#
#  conv2d_67 (Conv2D)          (None, 37, 37, 256)          590080    ['conv2d_66[0][0]']
#
#  conv2d_68 (Conv2D)          (None, 37, 37, 256)          590080    ['conv2d_67[0][0]']
#
#  add_2 (Add)                 (None, 37, 37, 256)          0         ['conv2d_68[0][0]',
#                                                                      'conv2d_66[0][0]']
#
#  max_pooling2d_32 (MaxPooli  (None, 18, 18, 256)          0         ['add_2[0][0]']
#  ng2D)
#
#  flatten_12 (Flatten)        (None, 82944)                0         ['max_pooling2d_32[0][0]']
#
#  dense_30 (Dense)            (None, 512)                  4246784   ['flatten_12[0][0]']
#                                                           0
#
#  dropout_30 (Dropout)        (None, 512)                  0         ['dense_30[0][0]']
#
#  dense_31 (Dense)            (None, 1)                    513       ['dropout_30[0][0]']
#
# ==================================================================================================
# Total params: 44387201 (169.32 MB)
# Trainable params: 44387201 (169.32 MB)
# Non-trainable params: 0 (0.00 Byte)
# __________________________________________________________________________________________________

# %% [markdown]
# Training

# %%
# Train a ResNet-like model for each class
trained_models_resnet = {}

for class_name, (x_train, x_val, y_train, y_val) in data.items():
    print(f"Training ResNet model for class: {class_name}")

    model = create_resnet_model(input_shape=(150, 150, 1))

    callbacks = [
        EarlyStopping(patience=15, restore_best_weights=True),
        ModelCheckpoint(f'/content/drive/MyDrive/TFG/kitchen-obj-classification/models/resnet_model_{class_name}.h5', save_best_only=True)
    ]

    # Train the model
    history = model.fit(
        x_train, y_train,
        validation_data=(x_val, y_val),
        epochs=50,
        batch_size=16,
        callbacks=callbacks
    )

    trained_models_resnet[class_name] = model

    print(f"ResNet model for class {class_name} trained and saved.")
# Out:
# Training ResNet model for class: sink
# Epoch 1/50
# 7/7 [==============================] - 29s 4s/step - loss: 2.1121 - accuracy: 0.4623 - val_loss: 2.6120 - val_accuracy: 0.4815
# Epoch 2/50
# 7/7 [==============================] - 9s 1s/step - loss: 1.1682 - accuracy: 0.5472 - val_loss: 0.9560 - val_accuracy: 0.4815
# Epoch 3/50
# 7/7 [==============================] - 4s 593ms/step - loss: 1.0977 - accuracy: 0.4528 - val_loss: 0.7412 - val_accuracy: 0.5185
# Epoch 4/50
# 7/7 [==============================] - 5s 796ms/step - loss: 0.7543 - accuracy: 0.5377 - val_loss: 0.6996 - val_accuracy: 0.4444
# Epoch 5/50
# 7/7 [==============================] - 6s 922ms/step - loss: 0.7005 - accuracy: 0.5189 - val_loss: 0.6938 - val_accuracy: 0.5556
# Epoch 6/50
# 7/7 [==============================] - 10s 2s/step - loss: 0.7155 - accuracy: 0.5377 - val_loss: 0.6931 - val_accuracy: 0.5185
# Epoch 7/50
# 7/7 [==============================] - 1s 145ms/step - loss: 0.6891 - accuracy: 0.5943 - val_loss: 0.7286 - val_accuracy: 0.5185
# Epoch 8/50
# 7/7 [==============================] - 4s 602ms/step - loss: 0.7116 - accuracy: 0.5283 - val_loss: 0.6884 - val_accuracy: 0.4444
# Epoch 9/50
# 7/7 [==============================] - 4s 679ms/step - loss: 0.6770 - accuracy: 0.5377 - val_loss: 0.6768 - val_accuracy: 0.5185
# Epoch 10/50
# 7/7 [==============================] - 4s 612ms/step - loss: 0.6601 - accuracy: 0.5566 - val_loss: 0.6698 - val_accuracy: 0.5185
# Epoch 11/50
# 7/7 [==============================] - 1s 132ms/step - loss: 0.6240 - accuracy: 0.5566 - val_loss: 0.7665 - val_accuracy: 0.5556
# Epoch 12/50
# 7/7 [==============================] - 3s 541ms/step - loss: 0.6493 - accuracy: 0.5849 - val_loss: 0.6649 - val_accuracy: 0.5185
# Epoch 13/50
# 7/7 [==============================] - 1s 135ms/step - loss: 0.6861 - accuracy: 0.5472 - val_loss: 0.7190 - val_accuracy: 0.4815
# Epoch 14/50
# 7/7 [==============================] - 1s 132ms/step - loss: 0.6604 - accuracy: 0.5377 - val_loss: 0.7652 - val_accuracy: 0.5926
# Epoch 15/50
# 7/7 [==============================] - 1s 129ms/step - loss: 0.5757 - accuracy: 0.7358 - val_loss: 1.0493 - val_accuracy: 0.4815
# Epoch 16/50
# 7/7 [==============================] - 1s 132ms/step - loss: 0.5758 - accuracy: 0.6604 - val_loss: 1.5832 - val_accuracy: 0.4444
# Epoch 17/50
# 7/7 [==============================] - 1s 134ms/step - loss: 0.5696 - accuracy: 0.6698 - val_loss: 2.7687 - val_accuracy: 0.4815
# Epoch 18/50
# 7/7 [==============================] - 1s 136ms/step - loss: 0.5990 - accuracy: 0.6698 - val_loss: 1.1559 - val_accuracy: 0.4444
# Epoch 19/50
# 7/7 [==============================] - 1s 151ms/step - loss: 0.5779 - accuracy: 0.6981 - val_loss: 2.4392 - val_accuracy: 0.4444
# Epoch 20/50
# 7/7 [==============================] - 1s 133ms/step - loss: 0.6133 - accuracy: 0.6415 - val_loss: 2.7655 - val_accuracy: 0.4815
# Epoch 21/50
# 7/7 [==============================] - 1s 135ms/step - loss: 0.5351 - accuracy: 0.7170 - val_loss: 1.9923 - val_accuracy: 0.4444
# Epoch 22/50
# 7/7 [==============================] - 1s 134ms/step - loss: 0.9636 - accuracy: 0.6792 - val_loss: 0.8178 - val_accuracy: 0.5556
# Epoch 23/50
# 7/7 [==============================] - 1s 133ms/step - loss: 0.5838 - accuracy: 0.7264 - val_loss: 0.7851 - val_accuracy: 0.3704
# Epoch 24/50
# 7/7 [==============================] - 1s 135ms/step - loss: 0.6519 - accuracy: 0.6132 - val_loss: 0.7740 - val_accuracy: 0.4815
# Epoch 25/50
# 7/7 [==============================] - 1s 135ms/step - loss: 0.6144 - accuracy: 0.6887 - val_loss: 0.8107 - val_accuracy: 0.4444
# Epoch 26/50
# 7/7 [==============================] - 1s 135ms/step - loss: 0.6665 - accuracy: 0.6604 - val_loss: 0.7585 - val_accuracy: 0.4444
# Epoch 27/50
# 7/7 [==============================] - 1s 176ms/step - loss: 0.6047 - accuracy: 0.6509 - val_loss: 0.7818 - val_accuracy: 0.5185
# ResNet model for class sink trained and saved.
# Training ResNet model for class: floor
# Epoch 1/50
# 8/8 [==============================] - 21s 2s/step - loss: 2.6965 - accuracy: 0.4474 - val_loss: 1.4793 - val_accuracy: 0.5172
# Epoch 2/50
# 8/8 [==============================] - 4s 478ms/step - loss: 0.9736 - accuracy: 0.4649 - val_loss: 0.9144 - val_accuracy: 0.5172
# Epoch 3/50
# 8/8 [==============================] - 9s 1s/step - loss: 0.7793 - accuracy: 0.5263 - val_loss: 0.7824 - val_accuracy: 0.5172
# Epoch 4/50
# 8/8 [==============================] - 1s 124ms/step - loss: 0.7273 - accuracy: 0.5088 - val_loss: 0.7916 - val_accuracy: 0.5172
# Epoch 5/50
# 8/8 [==============================] - 4s 551ms/step - loss: 0.7210 - accuracy: 0.5965 - val_loss: 0.7609 - val_accuracy: 0.5172
# Epoch 6/50
# 8/8 [==============================] - 4s 482ms/step - loss: 0.7013 - accuracy: 0.6053 - val_loss: 0.6957 - val_accuracy: 0.4828
# Epoch 7/50
# 8/8 [==============================] - 1s 133ms/step - loss: 0.7151 - accuracy: 0.5351 - val_loss: 0.7807 - val_accuracy: 0.5172
# Epoch 8/50
# 8/8 [==============================] - 1s 127ms/step - loss: 0.7168 - accuracy: 0.5351 - val_loss: 0.7131 - val_accuracy: 0.5172
# Epoch 9/50
# 8/8 [==============================] - 1s 136ms/step - loss: 0.6881 - accuracy: 0.6140 - val_loss: 0.8741 - val_accuracy: 0.5862
# Epoch 10/50
# 8/8 [==============================] - 1s 126ms/step - loss: 0.8073 - accuracy: 0.5702 - val_loss: 0.7900 - val_accuracy: 0.5172
# Epoch 11/50
# 8/8 [==============================] - 5s 761ms/step - loss: 0.7038 - accuracy: 0.6228 - val_loss: 0.6956 - val_accuracy: 0.4828
# Epoch 12/50
# 8/8 [==============================] - 1s 123ms/step - loss: 0.7964 - accuracy: 0.5526 - val_loss: 0.7370 - val_accuracy: 0.5172
# Epoch 13/50
# 8/8 [==============================] - 1s 122ms/step - loss: 0.6693 - accuracy: 0.6053 - val_loss: 0.7353 - val_accuracy: 0.5172
# Epoch 14/50
# 8/8 [==============================] - 1s 122ms/step - loss: 0.6728 - accuracy: 0.6053 - val_loss: 0.6958 - val_accuracy: 0.5172
# Epoch 15/50
# 8/8 [==============================] - 1s 121ms/step - loss: 0.6840 - accuracy: 0.5877 - val_loss: 0.7648 - val_accuracy: 0.5172
# Epoch 16/50
# 8/8 [==============================] - 4s 602ms/step - loss: 0.7141 - accuracy: 0.6053 - val_loss: 0.6921 - val_accuracy: 0.5172
# Epoch 17/50
# 8/8 [==============================] - 1s 121ms/step - loss: 0.7004 - accuracy: 0.5965 - val_loss: 0.7038 - val_accuracy: 0.5172
# Epoch 18/50
# 8/8 [==============================] - 1s 119ms/step - loss: 0.7099 - accuracy: 0.5965 - val_loss: 0.7003 - val_accuracy: 0.5172
# Epoch 19/50
# 8/8 [==============================] - 1s 121ms/step - loss: 0.6909 - accuracy: 0.5877 - val_loss: 0.6925 - val_accuracy: 0.5172
# Epoch 20/50
# 8/8 [==============================] - 1s 121ms/step - loss: 0.7124 - accuracy: 0.5000 - val_loss: 0.7362 - val_accuracy: 0.5172
# Epoch 21/50
# 8/8 [==============================] - 1s 131ms/step - loss: 0.7028 - accuracy: 0.6053 - val_loss: 0.7173 - val_accuracy: 0.5172
# Epoch 22/50
# 8/8 [==============================] - 1s 119ms/step - loss: 0.6829 - accuracy: 0.5702 - val_loss: 0.6928 - val_accuracy: 0.5172
# Epoch 23/50
# 8/8 [==============================] - 1s 121ms/step - loss: 0.6820 - accuracy: 0.6140 - val_loss: 0.7238 - val_accuracy: 0.5172
# Epoch 24/50
# 8/8 [==============================] - 1s 132ms/step - loss: 0.6701 - accuracy: 0.5965 - val_loss: 0.7047 - val_accuracy: 0.5172
# Epoch 25/50
# 8/8 [==============================] - 1s 120ms/step - loss: 0.6712 - accuracy: 0.6053 - val_loss: 0.7002 - val_accuracy: 0.5172
# Epoch 26/50
# 8/8 [==============================] - 1s 134ms/step - loss: 0.6714 - accuracy: 0.5965 - val_loss: 0.7215 - val_accuracy: 0.5172
# Epoch 27/50
# 8/8 [==============================] - 1s 132ms/step - loss: 0.6897 - accuracy: 0.5965 - val_loss: 0.7016 - val_accuracy: 0.5172
# Epoch 28/50
# 8/8 [==============================] - 1s 131ms/step - loss: 0.6788 - accuracy: 0.6053 - val_loss: 0.7078 - val_accuracy: 0.5172
# Epoch 29/50
# 8/8 [==============================] - 1s 128ms/step - loss: 0.6757 - accuracy: 0.6053 - val_loss: 0.7095 - val_accuracy: 0.5172
# Epoch 30/50
# 8/8 [==============================] - 1s 134ms/step - loss: 0.6699 - accuracy: 0.6053 - val_loss: 0.7009 - val_accuracy: 0.5172
# Epoch 31/50
# 8/8 [==============================] - 1s 161ms/step - loss: 0.6723 - accuracy: 0.6053 - val_loss: 0.7005 - val_accuracy: 0.5172
# ResNet model for class floor trained and saved.
# Training ResNet model for class: cabinet
# Epoch 1/50
# 12/12 [==============================] - 22s 2s/step - loss: 4.5892 - accuracy: 0.5316 - val_loss: 1.2274 - val_accuracy: 0.2708
# Epoch 2/50
# 12/12 [==============================] - 4s 372ms/step - loss: 0.8815 - accuracy: 0.4947 - val_loss: 0.7334 - val_accuracy: 0.2917
# Epoch 3/50
# 12/12 [==============================] - 5s 438ms/step - loss: 0.7094 - accuracy: 0.5474 - val_loss: 0.6051 - val_accuracy: 0.7292
# Epoch 4/50
# 12/12 [==============================] - 2s 136ms/step - loss: 0.6579 - accuracy: 0.6158 - val_loss: 0.6989 - val_accuracy: 0.3333
# Epoch 5/50
# 12/12 [==============================] - 2s 136ms/step - loss: 0.6605 - accuracy: 0.6263 - val_loss: 0.6222 - val_accuracy: 0.7292
# Epoch 6/50
# 12/12 [==============================] - 6s 563ms/step - loss: 0.6663 - accuracy: 0.6158 - val_loss: 0.5861 - val_accuracy: 0.7292
# Epoch 7/50
# 12/12 [==============================] - 5s 438ms/step - loss: 0.6905 - accuracy: 0.5842 - val_loss: 0.5858 - val_accuracy: 0.7292
# Epoch 8/50
# 12/12 [==============================] - 2s 140ms/step - loss: 0.6833 - accuracy: 0.5737 - val_loss: 0.7288 - val_accuracy: 0.3542
# Epoch 9/50
# 12/12 [==============================] - 2s 132ms/step - loss: 0.6667 - accuracy: 0.5789 - val_loss: 0.6000 - val_accuracy: 0.7292
# Epoch 10/50
# 12/12 [==============================] - 2s 136ms/step - loss: 0.6361 - accuracy: 0.6526 - val_loss: 0.6187 - val_accuracy: 0.7292
# Epoch 11/50
# 12/12 [==============================] - 2s 132ms/step - loss: 0.6155 - accuracy: 0.6526 - val_loss: 0.6000 - val_accuracy: 0.7292
# Epoch 12/50
# 12/12 [==============================] - 4s 357ms/step - loss: 0.6402 - accuracy: 0.6000 - val_loss: 0.5792 - val_accuracy: 0.7292
# Epoch 13/50
# 12/12 [==============================] - 2s 143ms/step - loss: 0.6460 - accuracy: 0.6368 - val_loss: 0.5856 - val_accuracy: 0.7292
# Epoch 14/50
# 12/12 [==============================] - 2s 140ms/step - loss: 0.6201 - accuracy: 0.6421 - val_loss: 0.5980 - val_accuracy: 0.7292
# Epoch 15/50
# 12/12 [==============================] - 5s 480ms/step - loss: 0.6038 - accuracy: 0.6474 - val_loss: 0.5762 - val_accuracy: 0.7292
# Epoch 16/50
# 12/12 [==============================] - 2s 137ms/step - loss: 0.5875 - accuracy: 0.6632 - val_loss: 0.5808 - val_accuracy: 0.7500
# Epoch 17/50
# 12/12 [==============================] - 2s 132ms/step - loss: 0.6008 - accuracy: 0.6526 - val_loss: 0.6040 - val_accuracy: 0.7500
# Epoch 18/50
# 12/12 [==============================] - 2s 136ms/step - loss: 0.5908 - accuracy: 0.6947 - val_loss: 0.5975 - val_accuracy: 0.7500
# Epoch 19/50
# 12/12 [==============================] - 7s 658ms/step - loss: 0.5843 - accuracy: 0.6737 - val_loss: 0.5740 - val_accuracy: 0.7500
# Epoch 20/50
# 12/12 [==============================] - 2s 131ms/step - loss: 0.5565 - accuracy: 0.6895 - val_loss: 0.6738 - val_accuracy: 0.6667
# Epoch 21/50
# 12/12 [==============================] - 2s 134ms/step - loss: 0.6022 - accuracy: 0.6947 - val_loss: 0.5994 - val_accuracy: 0.7292
# Epoch 22/50
# 12/12 [==============================] - 2s 131ms/step - loss: 0.6540 - accuracy: 0.6789 - val_loss: 0.6351 - val_accuracy: 0.7500
# Epoch 23/50
# 12/12 [==============================] - 2s 137ms/step - loss: 0.6381 - accuracy: 0.6526 - val_loss: 0.6042 - val_accuracy: 0.7292
# Epoch 24/50
# 12/12 [==============================] - 2s 136ms/step - loss: 0.5704 - accuracy: 0.6947 - val_loss: 0.6388 - val_accuracy: 0.7500
# Epoch 25/50
# 12/12 [==============================] - 2s 135ms/step - loss: 0.5262 - accuracy: 0.7000 - val_loss: 1.0480 - val_accuracy: 0.6875
# Epoch 26/50
# 12/12 [==============================] - 2s 138ms/step - loss: 0.6706 - accuracy: 0.6789 - val_loss: 0.6120 - val_accuracy: 0.7083
# Epoch 27/50
# 12/12 [==============================] - 2s 132ms/step - loss: 0.6309 - accuracy: 0.6421 - val_loss: 0.6132 - val_accuracy: 0.7292
# Epoch 28/50
# 12/12 [==============================] - 2s 132ms/step - loss: 0.6450 - accuracy: 0.6158 - val_loss: 0.6426 - val_accuracy: 0.7500
# Epoch 29/50
# 12/12 [==============================] - 6s 552ms/step - loss: 0.6397 - accuracy: 0.6421 - val_loss: 0.5645 - val_accuracy: 0.7292
# Epoch 30/50
# 12/12 [==============================] - 2s 136ms/step - loss: 0.5979 - accuracy: 0.6579 - val_loss: 0.6521 - val_accuracy: 0.7292
# Epoch 31/50
# 12/12 [==============================] - 9s 767ms/step - loss: 0.6421 - accuracy: 0.6684 - val_loss: 0.5196 - val_accuracy: 0.7708
# Epoch 32/50
# 12/12 [==============================] - 2s 132ms/step - loss: 0.5773 - accuracy: 0.6737 - val_loss: 0.5923 - val_accuracy: 0.7500
# Epoch 33/50
# 12/12 [==============================] - 2s 129ms/step - loss: 0.5804 - accuracy: 0.6737 - val_loss: 0.5516 - val_accuracy: 0.7708
# Epoch 34/50
# 12/12 [==============================] - 2s 136ms/step - loss: 0.5248 - accuracy: 0.7105 - val_loss: 0.7486 - val_accuracy: 0.7708
# Epoch 35/50
# 12/12 [==============================] - 2s 135ms/step - loss: 0.5805 - accuracy: 0.6842 - val_loss: 0.8749 - val_accuracy: 0.7708
# Epoch 36/50
# 12/12 [==============================] - 2s 132ms/step - loss: 0.6074 - accuracy: 0.6737 - val_loss: 0.5820 - val_accuracy: 0.7292
# Epoch 37/50
# 12/12 [==============================] - 2s 132ms/step - loss: 0.6141 - accuracy: 0.6632 - val_loss: 0.5655 - val_accuracy: 0.7292
# Epoch 38/50
# 12/12 [==============================] - 2s 132ms/step - loss: 0.5824 - accuracy: 0.6895 - val_loss: 0.5244 - val_accuracy: 0.7708
# Epoch 39/50
# 12/12 [==============================] - 2s 137ms/step - loss: 0.5599 - accuracy: 0.7000 - val_loss: 0.6018 - val_accuracy: 0.7292
# Epoch 40/50
# 12/12 [==============================] - 2s 136ms/step - loss: 0.6030 - accuracy: 0.6895 - val_loss: 0.5797 - val_accuracy: 0.7292
# Epoch 41/50
# 12/12 [==============================] - 2s 133ms/step - loss: 0.6168 - accuracy: 0.6526 - val_loss: 0.5713 - val_accuracy: 0.7292
# Epoch 42/50
# 12/12 [==============================] - 2s 133ms/step - loss: 0.5854 - accuracy: 0.6789 - val_loss: 0.6976 - val_accuracy: 0.7292
# Epoch 43/50
# 12/12 [==============================] - 2s 137ms/step - loss: 0.5769 - accuracy: 0.6947 - val_loss: 0.9806 - val_accuracy: 0.7083
# Epoch 44/50
# 12/12 [==============================] - 2s 141ms/step - loss: 0.5586 - accuracy: 0.7053 - val_loss: 0.6704 - val_accuracy: 0.7292
# Epoch 45/50
# 12/12 [==============================] - 2s 134ms/step - loss: 0.6835 - accuracy: 0.6158 - val_loss: 0.7918 - val_accuracy: 0.7292
# Epoch 46/50
# 12/12 [==============================] - 2s 158ms/step - loss: 0.6708 - accuracy: 0.6053 - val_loss: 0.6319 - val_accuracy: 0.7292
# ResNet model for class cabinet trained and saved.
# Training ResNet model for class: counter
# Epoch 1/50
# 11/11 [==============================] - 9s 599ms/step - loss: 2.9535 - accuracy: 0.4259 - val_loss: 3.8584 - val_accuracy: 0.6829
# Epoch 2/50
# 11/11 [==============================] - 8s 734ms/step - loss: 1.0312 - accuracy: 0.6420 - val_loss: 1.4708 - val_accuracy: 0.3415
# Epoch 3/50
# 11/11 [==============================] - 4s 378ms/step - loss: 0.7831 - accuracy: 0.5802 - val_loss: 0.6219 - val_accuracy: 0.6829
# Epoch 4/50
# 11/11 [==============================] - 2s 134ms/step - loss: 0.6845 - accuracy: 0.6173 - val_loss: 0.6768 - val_accuracy: 0.4878
# Epoch 5/50
# 11/11 [==============================] - 1s 131ms/step - loss: 0.6690 - accuracy: 0.5432 - val_loss: 0.6270 - val_accuracy: 0.6829
# Epoch 6/50
# 11/11 [==============================] - 7s 681ms/step - loss: 0.6401 - accuracy: 0.6481 - val_loss: 0.5920 - val_accuracy: 0.6829
# Epoch 7/50
# 11/11 [==============================] - 1s 128ms/step - loss: 0.7004 - accuracy: 0.6235 - val_loss: 0.6597 - val_accuracy: 0.6829
# Epoch 8/50
# 11/11 [==============================] - 1s 129ms/step - loss: 0.6911 - accuracy: 0.6296 - val_loss: 0.6545 - val_accuracy: 0.6829
# Epoch 9/50
# 11/11 [==============================] - 1s 125ms/step - loss: 0.6989 - accuracy: 0.6235 - val_loss: 0.6584 - val_accuracy: 0.6829
# Epoch 10/50
# 11/11 [==============================] - 1s 130ms/step - loss: 0.6713 - accuracy: 0.6235 - val_loss: 0.6501 - val_accuracy: 0.6829
# Epoch 11/50
# 11/11 [==============================] - 1s 133ms/step - loss: 0.6695 - accuracy: 0.6235 - val_loss: 0.6270 - val_accuracy: 0.6829
# Epoch 12/50
# 11/11 [==============================] - 1s 125ms/step - loss: 0.6758 - accuracy: 0.6296 - val_loss: 0.6977 - val_accuracy: 0.3171
# Epoch 13/50
# 11/11 [==============================] - 1s 123ms/step - loss: 0.7097 - accuracy: 0.5247 - val_loss: 0.6293 - val_accuracy: 0.6829
# Epoch 14/50
# 11/11 [==============================] - 1s 123ms/step - loss: 0.6606 - accuracy: 0.6235 - val_loss: 0.6444 - val_accuracy: 0.6829
# Epoch 15/50
# 11/11 [==============================] - 1s 128ms/step - loss: 0.6785 - accuracy: 0.6235 - val_loss: 0.6297 - val_accuracy: 0.6829
# Epoch 16/50
# 11/11 [==============================] - 1s 124ms/step - loss: 0.6582 - accuracy: 0.6235 - val_loss: 0.6271 - val_accuracy: 0.6829
# Epoch 17/50
# 11/11 [==============================] - 1s 124ms/step - loss: 0.6751 - accuracy: 0.6235 - val_loss: 0.6277 - val_accuracy: 0.6829
# Epoch 18/50
# 11/11 [==============================] - 1s 128ms/step - loss: 0.6890 - accuracy: 0.6235 - val_loss: 0.6331 - val_accuracy: 0.6829
# Epoch 19/50
# 11/11 [==============================] - 1s 125ms/step - loss: 0.6705 - accuracy: 0.6235 - val_loss: 0.6289 - val_accuracy: 0.6829
# Epoch 20/50
# 11/11 [==============================] - 1s 127ms/step - loss: 0.6629 - accuracy: 0.6235 - val_loss: 0.6311 - val_accuracy: 0.6829
# Epoch 21/50
# 11/11 [==============================] - 2s 172ms/step - loss: 0.6729 - accuracy: 0.6235 - val_loss: 0.6306 - val_accuracy: 0.6829
# ResNet model for class counter trained and saved.
# Training ResNet model for class: tiles
# Epoch 1/50
# 12/12 [==============================] - 23s 2s/step - loss: 3.5902 - accuracy: 0.5769 - val_loss: 0.9204 - val_accuracy: 0.5652
# Epoch 2/50
# 12/12 [==============================] - 5s 404ms/step - loss: 0.8031 - accuracy: 0.5385 - val_loss: 0.7385 - val_accuracy: 0.4348
# Epoch 3/50
# 12/12 [==============================] - 2s 130ms/step - loss: 0.7409 - accuracy: 0.5385 - val_loss: 0.7503 - val_accuracy: 0.5652
# Epoch 4/50
# 12/12 [==============================] - 2s 129ms/step - loss: 0.7142 - accuracy: 0.5165 - val_loss: 0.7793 - val_accuracy: 0.5652
# Epoch 5/50
# 12/12 [==============================] - 5s 479ms/step - loss: 0.7161 - accuracy: 0.5824 - val_loss: 0.6861 - val_accuracy: 0.5652
# Epoch 6/50
# 12/12 [==============================] - 7s 613ms/step - loss: 0.6828 - accuracy: 0.5879 - val_loss: 0.6839 - val_accuracy: 0.5652
# Epoch 7/50
# 12/12 [==============================] - 2s 130ms/step - loss: 0.6820 - accuracy: 0.5989 - val_loss: 0.6869 - val_accuracy: 0.5652
# Epoch 8/50
# 12/12 [==============================] - 2s 134ms/step - loss: 0.7587 - accuracy: 0.4890 - val_loss: 0.6912 - val_accuracy: 0.5652
# Epoch 9/50
# 12/12 [==============================] - 2s 135ms/step - loss: 0.7243 - accuracy: 0.5495 - val_loss: 0.7308 - val_accuracy: 0.4348
# Epoch 10/50
# 12/12 [==============================] - 2s 136ms/step - loss: 0.7142 - accuracy: 0.5385 - val_loss: 0.6930 - val_accuracy: 0.5652
# Epoch 11/50
# 12/12 [==============================] - 2s 135ms/step - loss: 1.3080 - accuracy: 0.6044 - val_loss: 0.6856 - val_accuracy: 0.5652
# Epoch 12/50
# 12/12 [==============================] - 2s 130ms/step - loss: 0.6930 - accuracy: 0.5604 - val_loss: 0.6927 - val_accuracy: 0.5652
# Epoch 13/50
# 12/12 [==============================] - 2s 138ms/step - loss: 0.7137 - accuracy: 0.5659 - val_loss: 0.6853 - val_accuracy: 0.5652
# Epoch 14/50
# 12/12 [==============================] - 2s 131ms/step - loss: 0.7295 - accuracy: 0.4725 - val_loss: 0.6869 - val_accuracy: 0.5652
# Epoch 15/50
# 12/12 [==============================] - 2s 132ms/step - loss: 0.6960 - accuracy: 0.5659 - val_loss: 0.7099 - val_accuracy: 0.5652
# Epoch 16/50
# 12/12 [==============================] - 2s 139ms/step - loss: 0.6927 - accuracy: 0.5824 - val_loss: 0.6865 - val_accuracy: 0.5652
# Epoch 17/50
# 12/12 [==============================] - 2s 142ms/step - loss: 0.6824 - accuracy: 0.5989 - val_loss: 0.6855 - val_accuracy: 0.5652
# Epoch 18/50
# 12/12 [==============================] - 2s 137ms/step - loss: 0.6801 - accuracy: 0.5989 - val_loss: 0.6873 - val_accuracy: 0.5652
# Epoch 19/50
# 12/12 [==============================] - 2s 128ms/step - loss: 0.6746 - accuracy: 0.6044 - val_loss: 0.6850 - val_accuracy: 0.5652
# Epoch 20/50
# 12/12 [==============================] - 2s 128ms/step - loss: 0.6662 - accuracy: 0.6044 - val_loss: 0.6881 - val_accuracy: 0.5652
# Epoch 21/50
# 12/12 [==============================] - 2s 155ms/step - loss: 0.6857 - accuracy: 0.5934 - val_loss: 0.6850 - val_accuracy: 0.5652
# ResNet model for class tiles trained and saved.
