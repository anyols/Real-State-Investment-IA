# %% [markdown]
# # **Bathroom Object Classification**

# %%
# Fundamental classes
import numpy as np
import pandas as pd
import tensorflow as tf
import os

# Image related
import cv2
from PIL import Image

#Performance Plot
from sklearn import metrics
from sklearn.metrics import f1_score, accuracy_score,confusion_matrix,classification_report
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# For the model and it's training
from sklearn.model_selection import train_test_split
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.models import Sequential, load_model, Model
from tensorflow.keras.layers import Conv2D, MaxPool2D, Dense, Flatten, Dropout, BatchNormalization, Input, Add
from tensorflow.keras.preprocessing.image import load_img, img_to_array

# Time
import time
import datetime

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# # Preprocessing

# %% [markdown]
# **Region Extraction from Images**

# %%
import os
import pandas as pd
import cv2
import numpy as np
from tensorflow.keras.preprocessing.image import img_to_array, load_img
from sklearn.model_selection import train_test_split

# Llegir el fitxer d'anotacions
annotations_path = '/content/drive/MyDrive/TFG/bathroom-obj-classification/_annotations_regions.csv'
annotations_df = pd.read_csv(annotations_path)

# Definir el camí de les imatges
IMAGES_PATH = '/content/drive/MyDrive/TFG/bathroom-obj-seg/train-dataset/images/'

# Funció per carregar i extreure les regions anotades per cada classe
def load_annotated_regions_for_class(annotations_df, class_name, images_path, target_size=(150, 150)):
    images = []
    labels = []
    class_df = annotations_df[annotations_df['class'] == class_name]
    for _, row in class_df.iterrows():
        img_path = os.path.join(images_path, row['filename'])
        image = load_img(img_path, color_mode='grayscale')
        image = img_to_array(image)
        x_min = int(row['xmin'])
        y_min = int(row['ymin'])
        x_max = int(row['xmax'])
        y_max = int(row['ymax'])
        region = image[y_min:y_max, x_min:x_max]
        region = cv2.resize(region, target_size)
        region = region / 255.0  # Normalitzar
        images.append(region)
        labels.append(row['labels'])
    return np.array(images), np.array(labels)

# Carregar les dades per cada classe
classes = ['sink', 'floor', 'cabinet', 'shower', 'tiles']
data = {}

for class_name in classes:
    x, y = load_annotated_regions_for_class(annotations_df, class_name, IMAGES_PATH)
    x_train, x_val, y_train, y_val = train_test_split(x, y, test_size=0.2, random_state=42)
    data[class_name] = (x_train, x_val, y_train, y_val)

# Mostrar un exemple de dades carregades
for class_name, (x_train, x_val, y_train, y_val) in data.items():
    print(f"Class: {class_name}, Train samples: {x_train.shape[0]}, Validation samples: {x_val.shape[0]}")
# Out:
# Class: sink, Train samples: 237, Validation samples: 60
# Class: floor, Train samples: 134, Validation samples: 34
# Class: cabinet, Train samples: 91, Validation samples: 23
# Class: shower, Train samples: 162, Validation samples: 41
# Class: tiles, Train samples: 362, Validation samples: 91

# %% [markdown]
# # Training

# %% [markdown]
# **Simple CNN**

# %% [markdown]
# Model

# %%
import tensorflow as tf
from tensorflow.keras import layers, models
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint

def create_simple_cnn(input_shape=(150, 150, 1)):
    model = models.Sequential([
        layers.Conv2D(32, (5, 5), activation='relu', input_shape=input_shape),
        layers.BatchNormalization(),
        layers.Conv2D(32, (5, 5), activation='relu'),
        layers.BatchNormalization(),
        layers.MaxPooling2D(pool_size=(2, 2)),
        layers.Dropout(rate=0.25),
        layers.Conv2D(64, (3, 3), activation='relu'),
        layers.BatchNormalization(),
        layers.Conv2D(64, (3, 3), activation='relu'),
        layers.BatchNormalization(),
        layers.MaxPooling2D(pool_size=(2, 2)),
        layers.Dropout(rate=0.25),
        layers.Flatten(),
        layers.Dense(256, activation='relu'),
        layers.Dropout(rate=0.5),
        layers.Dense(1, activation='sigmoid')
    ])

    model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])
    return model

create_simple_cnn().summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 146, 146, 32)      832
#
#  batch_normalization (Batch  (None, 146, 146, 32)      128
#  Normalization)
#
#  conv2d_1 (Conv2D)           (None, 142, 142, 32)      25632
#
#  batch_normalization_1 (Bat  (None, 142, 142, 32)      128
#  chNormalization)
#
#  max_pooling2d (MaxPooling2  (None, 71, 71, 32)        0
#  D)
#
#  dropout (Dropout)           (None, 71, 71, 32)        0
#
#  conv2d_2 (Conv2D)           (None, 69, 69, 64)        18496
#
#  batch_normalization_2 (Bat  (None, 69, 69, 64)        256
#  chNormalization)
#
#  conv2d_3 (Conv2D)           (None, 67, 67, 64)        36928
#
#  batch_normalization_3 (Bat  (None, 67, 67, 64)        256
#  chNormalization)
#
#  max_pooling2d_1 (MaxPoolin  (None, 33, 33, 64)        0
#  g2D)
#
#  dropout_1 (Dropout)         (None, 33, 33, 64)        0
#
#  flatten (Flatten)           (None, 69696)             0
#
#  dense (Dense)               (None, 256)               17842432
#
#  dropout_2 (Dropout)         (None, 256)               0
#
#  dense_1 (Dense)             (None, 1)                 257
#
# =================================================================
# Total params: 17925345 (68.38 MB)
# Trainable params: 17924961 (68.38 MB)
# Non-trainable params: 384 (1.50 KB)
# _________________________________________________________________

# %% [markdown]
# Training

# %%
# Train a simple CNN model for each class
trained_models_simple_cnn = {}

for class_name, (x_train, x_val, y_train, y_val) in data.items():
    print(f"Training simple CNN model for class: {class_name}")

    model = create_simple_cnn(input_shape=(150, 150, 1))

    # Define callbacks
    callbacks = [
        EarlyStopping(patience=10, restore_best_weights=True),
        ModelCheckpoint(f'/content/drive/MyDrive/TFG/bathroom-obj-classification/models/simple_cnn_model_{class_name}.h5', save_best_only=True)
    ]

    # Train the model
    history = model.fit(
        x_train, y_train,
        validation_data=(x_val, y_val),
        epochs=50,
        batch_size=16,
        callbacks=callbacks
    )

    trained_models_simple_cnn[class_name] = model

    print(f"Simple CNN model for class {class_name} trained and saved.")
# Out:
# Training simple CNN model for class: sink
# Epoch 1/50
# 15/15 [==============================] - ETA: 0s - loss: 10.2332 - accuracy: 0.5654
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 15/15 [==============================] - 15s 349ms/step - loss: 10.2332 - accuracy: 0.5654 - val_loss: 1.0907 - val_accuracy: 0.6667
# Epoch 2/50
# 15/15 [==============================] - 1s 55ms/step - loss: 12.0564 - accuracy: 0.7089 - val_loss: 5.8157 - val_accuracy: 0.6500
# Epoch 3/50
# 15/15 [==============================] - 1s 55ms/step - loss: 7.0687 - accuracy: 0.7890 - val_loss: 4.4497 - val_accuracy: 0.6500
# Epoch 4/50
# 15/15 [==============================] - 1s 55ms/step - loss: 6.1621 - accuracy: 0.8397 - val_loss: 1.2367 - val_accuracy: 0.4333
# Epoch 5/50
# 15/15 [==============================] - 1s 55ms/step - loss: 2.1790 - accuracy: 0.8565 - val_loss: 6.3218 - val_accuracy: 0.6500
# Epoch 6/50
# 15/15 [==============================] - 1s 56ms/step - loss: 1.0720 - accuracy: 0.9198 - val_loss: 5.0080 - val_accuracy: 0.6500
# Epoch 7/50
# 15/15 [==============================] - 1s 58ms/step - loss: 0.7701 - accuracy: 0.9494 - val_loss: 2.1666 - val_accuracy: 0.6833
# Epoch 8/50
# 15/15 [==============================] - 1s 57ms/step - loss: 0.5810 - accuracy: 0.9283 - val_loss: 9.6881 - val_accuracy: 0.3500
# Epoch 9/50
# 15/15 [==============================] - 1s 58ms/step - loss: 0.4094 - accuracy: 0.9494 - val_loss: 9.1773 - val_accuracy: 0.3500
# Epoch 10/50
# 15/15 [==============================] - 1s 54ms/step - loss: 0.5141 - accuracy: 0.9620 - val_loss: 5.3089 - val_accuracy: 0.6833
# Epoch 11/50
# 15/15 [==============================] - 1s 61ms/step - loss: 0.2853 - accuracy: 0.9705 - val_loss: 18.8496 - val_accuracy: 0.6500
# Simple CNN model for class sink trained and saved.
# Training simple CNN model for class: floor
# Epoch 1/50
# 9/9 [==============================] - 7s 454ms/step - loss: 13.6457 - accuracy: 0.6045 - val_loss: 3.6413 - val_accuracy: 0.5882
# Epoch 2/50
# 9/9 [==============================] - 0s 54ms/step - loss: 13.2291 - accuracy: 0.6716 - val_loss: 3.7546 - val_accuracy: 0.4118
# Epoch 3/50
# 9/9 [==============================] - 0s 53ms/step - loss: 10.8383 - accuracy: 0.7164 - val_loss: 17.2045 - val_accuracy: 0.5882
# Epoch 4/50
# 9/9 [==============================] - 1s 58ms/step - loss: 11.0141 - accuracy: 0.7463 - val_loss: 6.6693 - val_accuracy: 0.5882
# Epoch 5/50
# 9/9 [==============================] - 1s 58ms/step - loss: 8.1990 - accuracy: 0.7687 - val_loss: 7.7737 - val_accuracy: 0.5882
# Epoch 6/50
# 9/9 [==============================] - 1s 172ms/step - loss: 3.8886 - accuracy: 0.8358 - val_loss: 2.8226 - val_accuracy: 0.5882
# Epoch 7/50
# 9/9 [==============================] - 1s 58ms/step - loss: 4.1089 - accuracy: 0.8209 - val_loss: 6.6802 - val_accuracy: 0.4118
# Epoch 8/50
# 9/9 [==============================] - 0s 55ms/step - loss: 3.4637 - accuracy: 0.8731 - val_loss: 7.8231 - val_accuracy: 0.5882
# Epoch 9/50
# 9/9 [==============================] - 2s 235ms/step - loss: 2.6340 - accuracy: 0.8657 - val_loss: 2.2615 - val_accuracy: 0.5294
# Epoch 10/50
# 9/9 [==============================] - 1s 176ms/step - loss: 1.8431 - accuracy: 0.8881 - val_loss: 2.2088 - val_accuracy: 0.5294
# Epoch 11/50
# 9/9 [==============================] - 1s 58ms/step - loss: 2.6954 - accuracy: 0.8881 - val_loss: 7.5814 - val_accuracy: 0.5882
# Epoch 12/50
# 9/9 [==============================] - 0s 53ms/step - loss: 0.9144 - accuracy: 0.9478 - val_loss: 12.5906 - val_accuracy: 0.5882
# Epoch 13/50
# 9/9 [==============================] - 1s 60ms/step - loss: 0.5866 - accuracy: 0.9478 - val_loss: 6.2630 - val_accuracy: 0.5882
# Epoch 14/50
# 9/9 [==============================] - 1s 59ms/step - loss: 1.2783 - accuracy: 0.9104 - val_loss: 4.0877 - val_accuracy: 0.5294
# Epoch 15/50
# 9/9 [==============================] - 1s 58ms/step - loss: 2.2039 - accuracy: 0.9403 - val_loss: 23.5592 - val_accuracy: 0.5882
# Epoch 16/50
# 9/9 [==============================] - 1s 64ms/step - loss: 1.5579 - accuracy: 0.9254 - val_loss: 41.5198 - val_accuracy: 0.5882
# Epoch 17/50
# 9/9 [==============================] - 1s 62ms/step - loss: 2.2596 - accuracy: 0.9254 - val_loss: 26.0076 - val_accuracy: 0.5882
# Epoch 18/50
# 9/9 [==============================] - 1s 58ms/step - loss: 0.4885 - accuracy: 0.9701 - val_loss: 18.9707 - val_accuracy: 0.5882
# Epoch 19/50
# 9/9 [==============================] - 1s 63ms/step - loss: 0.9371 - accuracy: 0.9328 - val_loss: 33.3402 - val_accuracy: 0.5882
# Epoch 20/50
# 9/9 [==============================] - 1s 74ms/step - loss: 0.7703 - accuracy: 0.9552 - val_loss: 21.3373 - val_accuracy: 0.5882
# Simple CNN model for class floor trained and saved.
# Training simple CNN model for class: cabinet
# Epoch 1/50
# 6/6 [==============================] - 7s 745ms/step - loss: 26.3378 - accuracy: 0.4066 - val_loss: 1.3735 - val_accuracy: 0.4348
# Epoch 2/50
# 6/6 [==============================] - 0s 58ms/step - loss: 8.7266 - accuracy: 0.6703 - val_loss: 5.6158 - val_accuracy: 0.4348
# Epoch 3/50
# 11/11 [==============================] - 1s 66ms/step - loss: 1.2597 - accuracy: 0.9321 - val_loss: 1.3676 - val_accuracy: 0.5366
# Simple CNN model for class shower trained and saved.
# Training simple CNN model for class: tiles
# Epoch 1/50
# 23/23 [==============================] - 8s 187ms/step - loss: 18.9167 - accuracy: 0.4972 - val_loss: 2.5335 - val_accuracy: 0.4945
# Epoch 2/50
# 23/23 [==============================] - 1s 54ms/step - loss: 7.6589 - accuracy: 0.5497 - val_loss: 3.6464 - val_accuracy: 0.4945
# Epoch 3/50
# 23/23 [==============================] - 4s 191ms/step - loss: 4.1047 - accuracy: 0.5663 - val_loss: 0.9302 - val_accuracy: 0.4505
# Epoch 4/50
# 23/23 [==============================] - 1s 58ms/step - loss: 2.9288 - accuracy: 0.6105 - val_loss: 7.8781 - val_accuracy: 0.5165
# Epoch 5/50
# 23/23 [==============================] - 1s 58ms/step - loss: 1.4102 - accuracy: 0.6215 - val_loss: 6.0791 - val_accuracy: 0.5165
# Epoch 6/50
# 23/23 [==============================] - 1s 61ms/step - loss: 0.6517 - accuracy: 0.6630 - val_loss: 2.9401 - val_accuracy: 0.5495
# Epoch 7/50
# 23/23 [==============================] - 1s 55ms/step - loss: 0.5861 - accuracy: 0.6878 - val_loss: 10.0830 - val_accuracy: 0.5165
# Epoch 8/50
# 23/23 [==============================] - 1s 55ms/step - loss: 0.5828 - accuracy: 0.6685 - val_loss: 18.7365 - val_accuracy: 0.5165
# Epoch 9/50
# 23/23 [==============================] - 1s 54ms/step - loss: 0.5598 - accuracy: 0.6851 - val_loss: 19.3607 - val_accuracy: 0.5165
# Epoch 10/50
# 23/23 [==============================] - 1s 55ms/step - loss: 0.5052 - accuracy: 0.7486 - val_loss: 14.1826 - val_accuracy: 0.5165
# Epoch 11/50
# 23/23 [==============================] - 1s 56ms/step - loss: 0.4083 - accuracy: 0.8066 - val_loss: 10.5022 - val_accuracy: 0.5275
# Epoch 12/50
# 23/23 [==============================] - 1s 56ms/step - loss: 0.4117 - accuracy: 0.8039 - val_loss: 12.3896 - val_accuracy: 0.5275
# Epoch 13/50
# 23/23 [==============================] - 1s 61ms/step - loss: 0.4478 - accuracy: 0.7707 - val_loss: 11.2709 - val_accuracy: 0.5165
# Simple CNN model for class tiles trained and saved.

# %% [markdown]
# **VGG**

# %% [markdown]
# Model

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout

def create_vgg_model(input_shape=(150, 150, 1)):
    model = Sequential([
        Conv2D(64, (3, 3), activation='relu', padding='same', input_shape=input_shape),
        Conv2D(64, (3, 3), activation='relu', padding='same'),
        MaxPooling2D(pool_size=(2, 2)),

        Conv2D(128, (3, 3), activation='relu', padding='same'),
        Conv2D(128, (3, 3), activation='relu', padding='same'),
        MaxPooling2D(pool_size=(2, 2)),

        Conv2D(256, (3, 3), activation='relu', padding='same'),
        Conv2D(256, (3, 3), activation='relu', padding='same'),
        MaxPooling2D(pool_size=(2, 2)),

        Flatten(),
        Dense(512, activation='relu'),
        Dropout(0.5),
        Dense(512, activation='relu'),
        Dropout(0.5),
        Dense(1, activation='sigmoid')
    ])

    model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])
    return model

create_vgg_model().summary()
# Out:
# Model: "sequential_6"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_24 (Conv2D)          (None, 150, 150, 64)      640
#
#  conv2d_25 (Conv2D)          (None, 150, 150, 64)      36928
#
#  max_pooling2d_12 (MaxPooli  (None, 75, 75, 64)        0
#  ng2D)
#
#  conv2d_26 (Conv2D)          (None, 75, 75, 128)       73856
#
#  conv2d_27 (Conv2D)          (None, 75, 75, 128)       147584
#
#  max_pooling2d_13 (MaxPooli  (None, 37, 37, 128)       0
#  ng2D)
#
#  conv2d_28 (Conv2D)          (None, 37, 37, 256)       295168
#
#  conv2d_29 (Conv2D)          (None, 37, 37, 256)       590080
#
#  max_pooling2d_14 (MaxPooli  (None, 18, 18, 256)       0
#  ng2D)
#
#  flatten_6 (Flatten)         (None, 82944)             0
#
#  dense_12 (Dense)            (None, 512)               42467840
#
#  dropout_18 (Dropout)        (None, 512)               0
#
#  dense_13 (Dense)            (None, 512)               262656
#
#  dropout_19 (Dropout)        (None, 512)               0
#
#  dense_14 (Dense)            (None, 1)                 513
#
# =================================================================
# Total params: 43875265 (167.37 MB)
# Trainable params: 43875265 (167.37 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %% [markdown]
# Training

# %%
# Train a VGG-like model for each class
trained_models_vgg = {}

for class_name, (x_train, x_val, y_train, y_val) in data.items():
    print(f"Training VGG model for class: {class_name}")

    model = create_vgg_model(input_shape=(150, 150, 1))

    # Define callbacks
    callbacks = [
        EarlyStopping(patience=15, restore_best_weights=True),
        ModelCheckpoint(f'/content/drive/MyDrive/TFG/bathroom-obj-classification/models/vgg_model_{class_name}.h5', save_best_only=True)
    ]

    # Train the model
    history = model.fit(
        x_train, y_train,
        validation_data=(x_val, y_val),
        epochs=50,
        batch_size=16,
        callbacks=callbacks
    )

    trained_models_vgg[class_name] = model

    print(f"VGG model for class {class_name} trained and saved.")
# Out:
# Training VGG model for class: sink
# Epoch 1/50
# 15/15 [==============================] - 19s 797ms/step - loss: 0.7029 - accuracy: 0.5781 - val_loss: 0.6822 - val_accuracy: 0.6500
# Epoch 2/50
# 15/15 [==============================] - 4s 269ms/step - loss: 0.6975 - accuracy: 0.6287 - val_loss: 0.6777 - val_accuracy: 0.6500
# Epoch 3/50
# 15/15 [==============================] - 5s 314ms/step - loss: 0.6793 - accuracy: 0.6160 - val_loss: 0.6531 - val_accuracy: 0.6500
# Epoch 4/50
# 15/15 [==============================] - 5s 335ms/step - loss: 0.6698 - accuracy: 0.6160 - val_loss: 0.6515 - val_accuracy: 0.6500
# Epoch 5/50
# 15/15 [==============================] - 1s 88ms/step - loss: 0.6763 - accuracy: 0.6160 - val_loss: 0.6581 - val_accuracy: 0.6500
# Epoch 6/50
# 15/15 [==============================] - 4s 262ms/step - loss: 0.6768 - accuracy: 0.6160 - val_loss: 0.6515 - val_accuracy: 0.6500
# Epoch 7/50
# 15/15 [==============================] - 1s 91ms/step - loss: 0.6719 - accuracy: 0.6160 - val_loss: 0.6592 - val_accuracy: 0.6500
# Epoch 8/50
# 15/15 [==============================] - 4s 297ms/step - loss: 0.6671 - accuracy: 0.6160 - val_loss: 0.6477 - val_accuracy: 0.6500
# Epoch 9/50
# 15/15 [==============================] - 6s 420ms/step - loss: 0.6699 - accuracy: 0.6203 - val_loss: 0.6393 - val_accuracy: 0.6500
# Epoch 10/50
# 15/15 [==============================] - 6s 424ms/step - loss: 0.6609 - accuracy: 0.6160 - val_loss: 0.6219 - val_accuracy: 0.6833
# Epoch 11/50
# 15/15 [==============================] - 1s 85ms/step - loss: 0.6626 - accuracy: 0.6245 - val_loss: 0.6328 - val_accuracy: 0.6833
# Epoch 12/50
# 15/15 [==============================] - 1s 81ms/step - loss: 0.6654 - accuracy: 0.6624 - val_loss: 0.6499 - val_accuracy: 0.6833
# Epoch 13/50
# Epoch 4/50
# 9/9 [==============================] - 1s 87ms/step - loss: 0.6670 - accuracy: 0.6567 - val_loss: 0.6984 - val_accuracy: 0.5882
# Epoch 5/50
# 9/9 [==============================] - 1s 85ms/step - loss: 0.7323 - accuracy: 0.6567 - val_loss: 0.6831 - val_accuracy: 0.5882
# Epoch 6/50
# 9/9 [==============================] - 1s 85ms/step - loss: 0.6821 - accuracy: 0.6567 - val_loss: 0.6869 - val_accuracy: 0.5882
# Epoch 7/50
# 9/9 [==============================] - 1s 81ms/step - loss: 0.6769 - accuracy: 0.6567 - val_loss: 0.6793 - val_accuracy: 0.5882
# Epoch 8/50
# 9/9 [==============================] - 1s 86ms/step - loss: 0.6586 - accuracy: 0.6567 - val_loss: 0.6882 - val_accuracy: 0.5882
# Epoch 9/50
# 9/9 [==============================] - 1s 84ms/step - loss: 0.6466 - accuracy: 0.6567 - val_loss: 0.6807 - val_accuracy: 0.5882
# Epoch 10/50
# 9/9 [==============================] - 1s 82ms/step - loss: 0.6475 - accuracy: 0.6567 - val_loss: 0.6829 - val_accuracy: 0.5882
# Epoch 11/50
# 9/9 [==============================] - 3s 356ms/step - loss: 0.6532 - accuracy: 0.6567 - val_loss: 0.6759 - val_accuracy: 0.5882
# Epoch 12/50
# 9/9 [==============================] - 8s 925ms/step - loss: 0.6530 - accuracy: 0.6567 - val_loss: 0.6743 - val_accuracy: 0.5882
# Epoch 13/50
# 9/9 [==============================] - 1s 88ms/step - loss: 0.6416 - accuracy: 0.6567 - val_loss: 0.6838 - val_accuracy: 0.5882
# Epoch 14/50
# 9/9 [==============================] - 1s 85ms/step - loss: 0.6248 - accuracy: 0.6866 - val_loss: 0.6992 - val_accuracy: 0.5588
# Epoch 15/50
# 9/9 [==============================] - 1s 85ms/step - loss: 0.5903 - accuracy: 0.7164 - val_loss: 0.7856 - val_accuracy: 0.5882
# Epoch 16/50
# 9/9 [==============================] - 1s 82ms/step - loss: 0.5970 - accuracy: 0.7313 - val_loss: 0.7618 - val_accuracy: 0.5882
# Epoch 17/50
# 9/9 [==============================] - 1s 82ms/step - loss: 0.6443 - accuracy: 0.6791 - val_loss: 0.7078 - val_accuracy: 0.5882
# Epoch 18/50
# 9/9 [==============================] - 1s 81ms/step - loss: 0.6417 - accuracy: 0.6716 - val_loss: 0.7149 - val_accuracy: 0.5882
# Epoch 19/50
# 9/9 [==============================] - 1s 80ms/step - loss: 0.6262 - accuracy: 0.6567 - val_loss: 0.7180 - val_accuracy: 0.5882
# Epoch 20/50
# 9/9 [==============================] - 1s 80ms/step - loss: 0.6212 - accuracy: 0.6866 - val_loss: 0.7390 - val_accuracy: 0.5588
# Epoch 21/50
# 9/9 [==============================] - 1s 80ms/step - loss: 0.5855 - accuracy: 0.7313 - val_loss: 0.7738 - val_accuracy: 0.5882
# Epoch 22/50
# 9/9 [==============================] - 1s 83ms/step - loss: 0.6727 - accuracy: 0.7313 - val_loss: 0.6873 - val_accuracy: 0.5588
# Epoch 23/50
# 9/9 [==============================] - 1s 84ms/step - loss: 0.6318 - accuracy: 0.6791 - val_loss: 0.6835 - val_accuracy: 0.5882
# Epoch 24/50
# 9/9 [==============================] - 1s 85ms/step - loss: 0.6452 - accuracy: 0.6567 - val_loss: 0.7010 - val_accuracy: 0.5882
# Epoch 25/50
# 9/9 [==============================] - 1s 84ms/step - loss: 0.6342 - accuracy: 0.6493 - val_loss: 0.7403 - val_accuracy: 0.5588
# Epoch 26/50
# 9/9 [==============================] - 1s 85ms/step - loss: 0.6035 - accuracy: 0.6866 - val_loss: 0.7924 - val_accuracy: 0.5588
# Epoch 27/50
# 9/9 [==============================] - 1s 119ms/step - loss: 0.6310 - accuracy: 0.7090 - val_loss: 0.8964 - val_accuracy: 0.5882
# VGG model for class floor trained and saved.
# Training VGG model for class: cabinet
# Epoch 1/50
# 6/6 [==============================] - 13s 2s/step - loss: 0.7140 - accuracy: 0.4286 - val_loss: 0.6939 - val_accuracy: 0.4348
# Epoch 2/50
# 6/6 [==============================] - 1s 90ms/step - loss: 0.6946 - accuracy: 0.4725 - val_loss: 0.7052 - val_accuracy: 0.4348
# Epoch 3/50
# 6/6 [==============================] - 1s 85ms/step - loss: 0.6936 - accuracy: 0.5604 - val_loss: 0.6966 - val_accuracy: 0.4348
# Epoch 4/50
# 6/6 [==============================] - 1s 85ms/step - loss: 0.6889 - accuracy: 0.5604 - val_loss: 0.6996 - val_accuracy: 0.4348
# Epoch 5/50
# 6/6 [==============================] - 1s 92ms/step - loss: 0.6899 - accuracy: 0.5604 - val_loss: 0.7141 - val_accuracy: 0.4348
# Epoch 6/50
# 6/6 [==============================] - 1s 91ms/step - loss: 0.6915 - accuracy: 0.5604 - val_loss: 0.7239 - val_accuracy: 0.4348
# Epoch 7/50
# 6/6 [==============================] - 1s 91ms/step - loss: 0.6836 - accuracy: 0.5604 - val_loss: 0.7036 - val_accuracy: 0.4348
# Epoch 8/50
# 6/6 [==============================] - 1s 95ms/step - loss: 0.6895 - accuracy: 0.5714 - val_loss: 0.6995 - val_accuracy: 0.4348
# Epoch 9/50
# 6/6 [==============================] - 1s 89ms/step - loss: 0.6850 - accuracy: 0.5714 - val_loss: 0.7010 - val_accuracy: 0.4348
# Epoch 10/50
# 6/6 [==============================] - 1s 95ms/step - loss: 0.6866 - accuracy: 0.5495 - val_loss: 0.7070 - val_accuracy: 0.4348
# Epoch 11/50
# 6/6 [==============================] - 1s 97ms/step - loss: 0.6820 - accuracy: 0.5604 - val_loss: 0.7200 - val_accuracy: 0.4348
# Epoch 12/50
# 6/6 [==============================] - 1s 96ms/step - loss: 0.6870 - accuracy: 0.5604 - val_loss: 0.7110 - val_accuracy: 0.4348
# Epoch 13/50
# 6/6 [==============================] - 1s 95ms/step - loss: 0.6949 - accuracy: 0.5714 - val_loss: 0.7139 - val_accuracy: 0.4348
# Epoch 14/50
# 6/6 [==============================] - 1s 91ms/step - loss: 0.6848 - accuracy: 0.5495 - val_loss: 0.7128 - val_accuracy: 0.4348
Conv2D, MaxPooling2D, Flatten, Dense, Dropout
from tensorflow.keras.models import Model

def resnet_block(input_tensor, filters, kernel_size=3):
    x = Conv2D(filters, (kernel_size, kernel_size), padding='same', activation='relu')(input_tensor)
    x = Conv2D(filters, (kernel_size, kernel_size), padding='same')(x)
    x = Add()([x, input_tensor])
    return x

def create_resnet_model(input_shape=(150, 150, 1)):
    inputs = Input(shape=input_shape)
    x = Conv2D(64, (3, 3), activation='relu', padding='same')(inputs)
    x = resnet_block(x, 64)
    x = MaxPooling2D(pool_size=(2, 2))(x)

    x = Conv2D(128, (3, 3), activation='relu', padding='same')(x)
    x = resnet_block(x, 128)
    x = MaxPooling2D(pool_size=(2, 2))(x)

    x = Conv2D(256, (3, 3), activation='relu', padding='same')(x)
    x = resnet_block(x, 256)
    x = MaxPooling2D(pool_size=(2, 2))(x)

    x = Flatten()(x)
    x = Dense(512, activation='relu')(x)
    x = Dropout(0.5)(x)
    outputs = Dense(1, activation='sigmoid')(x)

    model = Model(inputs, outputs)
    model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])
    return model

create_resnet_model().summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_1 (InputLayer)        [(None, 150, 150, 1)]        0         []
#
#  conv2d_60 (Conv2D)          (None, 150, 150, 64)         640       ['input_1[0][0]']
#
#  conv2d_61 (Conv2D)          (None, 150, 150, 64)         36928     ['conv2d_60[0][0]']
#
#  conv2d_62 (Conv2D)          (None, 150, 150, 64)         36928     ['conv2d_61[0][0]']
#
#  add (Add)                   (None, 150, 150, 64)         0         ['conv2d_62[0][0]',
#                                                                      'conv2d_60[0][0]']
#
#  max_pooling2d_30 (MaxPooli  (None, 75, 75, 64)           0         ['add[0][0]']
#  ng2D)
#
#  conv2d_63 (Conv2D)          (None, 75, 75, 128)          73856     ['max_pooling2d_30[0][0]']
#
#  conv2d_64 (Conv2D)          (None, 75, 75, 128)          147584    ['conv2d_63[0][0]']
#
#  conv2d_65 (Conv2D)          (None, 75, 75, 128)          147584    ['conv2d_64[0][0]']
#
#  add_1 (Add)                 (None, 75, 75, 128)          0         ['conv2d_65[0][0]',
#                                                                      'conv2d_63[0][0]']
#
#  max_pooling2d_31 (MaxPooli  (None, 37, 37, 128)          0         ['add_1[0][0]']
#  ng2D)
#
#  conv2d_66 (Conv2D)          (None, 37, 37, 256)          295168    ['max_pooling2d_31[0][0]']
#
#  conv2d_67 (Conv2D)          (None, 37, 37, 256)          590080    ['conv2d_66[0][0]']
#
#  conv2d_68 (Conv2D)          (None, 37, 37, 256)          590080    ['conv2d_67[0][0]']
#
#  add_2 (Add)                 (None, 37, 37, 256)          0         ['conv2d_68[0][0]',
#                                                                      'conv2d_66[0][0]']
#
#  max_pooling2d_32 (MaxPooli  (None, 18, 18, 256)          0         ['add_2[0][0]']
#  ng2D)
#
#  flatten_12 (Flatten)        (None, 82944)                0         ['max_pooling2d_32[0][0]']
#
#  dense_30 (Dense)            (None, 512)                  4246784   ['flatten_12[0][0]']
#                                                           0
#
#  dropout_30 (Dropout)        (None, 512)                  0         ['dense_30[0][0]']
#
#  dense_31 (Dense)            (None, 1)                    513       ['dropout_30[0][0]']
#
# ==================================================================================================
# Total params: 44387201 (169.32 MB)
# Trainable params: 44387201 (169.32 MB)
# Non-trainable params: 0 (0.00 Byte)
# __________________________________________________________________________________________________

# %% [markdown]
# Training

# %%
# Train a ResNet-like model for each class
trained_models_resnet = {}

for class_name, (x_train, x_val, y_train, y_val) in data.items():
    print(f"Training ResNet model for class: {class_name}")

    model = create_resnet_model(input_shape=(150, 150, 1))

    callbacks = [
        EarlyStopping(patience=15, restore_best_weights=True),
        ModelCheckpoint(f'/content/drive/MyDrive/TFG/bathroom-obj-classification/models/resnet_model_{class_name}.h5', save_best_only=True)
    ]

    # Train the model
    history = model.fit(
        x_train, y_train,
        validation_data=(x_val, y_val),
        epochs=50,
        batch_size=16,
        callbacks=callbacks
    )

    trained_models_resnet[class_name] = model

    print(f"ResNet model for class {class_name} trained and saved.")
# Out:
# Training ResNet model for class: sink
# Epoch 1/50
# 15/15 [==============================] - 14s 670ms/step - loss: 2.9836 - accuracy: 0.5063 - val_loss: 0.6199 - val_accuracy: 0.6833
# Epoch 2/50
# 15/15 [==============================] - 2s 133ms/step - loss: 0
50
# 15/15 [==============================] - 2s 133ms/step - loss: 0.3815 - accuracy: 0.8354 - val_loss: 0.6440 - val_accuracy: 0.7333
# Epoch 43/50
# 15/15 [==============================] - 2s 132ms/step - loss: 0.3985 - accuracy: 0.8354 - val_loss: 0.6900 - val_accuracy: 0.7333
# Epoch 44/50
# 15/15 [==============================] - 2s 133ms/step - loss: 0.3721 - accuracy: 0.8565 - val_loss: 0.6486 - val_accuracy: 0.7667
# Epoch 45/50
# 15/15 [==============================] - 2s 134ms/step - loss: 0.4080 - accuracy: 0.8608 - val_loss: 0.7413 - val_accuracy: 0.7000
# Epoch 46/50
# 15/15 [==============================] - 2s 136ms/step - loss: 0.3402 - accuracy: 0.8565 - val_loss: 0.7295 - val_accuracy: 0.7000
# Epoch 47/50
# 15/15 [==============================] - 2s 151ms/step - loss: 0.2637 - accuracy: 0.8945 - val_loss: 0.7078 - val_accuracy: 0.7500
# ResNet model for class sink trained and saved.
# Training ResNet model for class: floor
# Epoch 1/50
# 9/9 [==============================] - 12s 1s/step - loss: 1.5905 - accuracy: 0.5522 - val_loss: 0.8311 - val_accuracy: 0.5882
# Epoch 2/50
# 9/9 [==============================] - 10s 1s/step - loss: 0.6950 - accuracy: 0.6418 - val_loss: 0.6825 - val_accuracy: 0.5588
# Epoch 3/50
# 9/9 [==============================] - 1s 138ms/step - loss: 0.6772 - accuracy: 0.6493 - val_loss: 0.6846 - val_accuracy: 0.5882
# Epoch 4/50
# 9/9 [==============================] - 1s 126ms/step - loss: 0.6637 - accuracy: 0.6343 - val_loss: 0.7304 - val_accuracy: 0.4118
# Epoch 5/50
# 9/9 [==============================] - 1s 126ms/step - loss: 0.6748 - accuracy: 0.5373 - val_loss: 0.7260 - val_accuracy: 0.4118
# Epoch 6/50
# 9/9 [==============================] - 1s 134ms/step - loss: 0.6908 - accuracy: 0.6343 - val_loss: 0.7164 - val_accuracy: 0.5588
# Epoch 7/50
# 9/9 [==============================] - 1s 137ms/step - loss: 0.6163 - accuracy: 0.6866 - val_loss: 0.7268 - val_accuracy: 0.5588
# Epoch 8/50
# 9/9 [==============================] - 1s 137ms/step - loss: 0.6023 - accuracy: 0.7164 - val_loss: 1.0041 - val_accuracy: 0.4118
# Epoch 9/50
# 9/9 [==============================] - 1s 130ms/step - loss: 0.6708 - accuracy: 0.7015 - val_loss: 0.7282 - val_accuracy: 0.5588
# Epoch 10/50
# 9/9 [==============================] - 1s 138ms/step - loss: 0.5880 - accuracy: 0.6866 - val_loss: 1.3698 - val_accuracy: 0.5588
# Epoch 11/50
# 9/9 [==============================] - 1s 138ms/step - loss: 0.6549 - accuracy: 0.7313 - val_loss: 2.0101 - val_accuracy: 0.5588
# Epoch 12/50
# 9/9 [==============================] - 8s 933ms/step - loss: 0.5824 - accuracy: 0.7164 - val_loss: 0.6748 - val_accuracy: 0.5882
# Epoch 13/50
# 9/9 [==============================] - 4s 466ms/step - loss: 0.6282 - accuracy: 0.6791 - val_loss: 0.6641 - val_accuracy: 0.6471
# Epoch 14/50
# 9/9 [==============================] - 1s 139ms/step - loss: 0.6720 - accuracy: 0.6642 - val_loss: 0.9165 - val_accuracy: 0.5882
# Epoch 15/50
# 9/9 [==============================] - 1s 136ms/step - loss: 1.5680 - accuracy: 0.6418 - val_loss: 0.9024 - val_accuracy: 0.2647
# Epoch 16/50
# 9/9 [==============================] - 1s 140ms/step - loss: 0.8533 - accuracy: 0.5821 - val_loss: 0.9649 - val_accuracy: 0.4118
# Epoch 17/50
# 9/9 [==============================] - 1s 138ms/step - loss: 0.7021 - accuracy: 0.5896 - val_loss: 0.7579 - val_accuracy: 0.4118
# Epoch 18/50
# 9/9 [==============================] - 1s 146ms/step - loss: 0.8622 - accuracy: 0.6269 - val_loss: 0.7282 - val_accuracy: 0.5882
# Epoch 19/50
# 9/9 [==============================] - 1s 139ms/step - loss: 0.6859 - accuracy: 0.6194 - val_loss: 0.7292 - val_accuracy: 0.5882
# Epoch 20/50
# 9/9 [==============================] - 1s 131ms/step - loss: 0.6271 - accuracy: 0.6119 - val_loss: 0.7388 - val_accuracy: 0.5882
# Epoch 21/50
# 9/9 [==============================] - 1s 127ms/step - loss: 0.6702 - accuracy: 0.6493 - val_loss: 0.6786 - val_accuracy: 0.6176
# Epoch 22/50
# 9/9 [==============================] - 1s 131ms/step - loss: 0.6295 - accuracy: 0.6493 - val_loss: 0.7009 - val_accuracy: 0.5882
# Epoch 23/50
# 9/9 [==============================] - 1s 133ms/step - loss: 0.5696 - accuracy: 0.6940 - val_loss: 0.7273 - val_accuracy: 0.5588
# Epoch 24/50
# 9/9 [==============================] - 1s 140ms/step - loss: 0.5852 - accuracy: 0.7388 - val_loss: 0.9733 - val_accuracy: 0.6176
# Epoch 25/50
# 9/9 [==============================] - 1s 137ms/step - loss: 0.7348 - accuracy: 0.7463 - val_loss: 0.6966 - val_accuracy: 0.6176
# Epoch 26/50
# 9/9 [==============================] - 1s 136ms/step - loss: 0.5567 - accuracy: 0.7388 - val_loss: 0.7536 - val_accuracy: 0.6176
# Epoch 27/50
# 9/9 [==============================] - 1s 129ms/step - loss: 0.6599 - accuracy: 0.6567 - val_loss: 0.6914 - val_accuracy: 0.5588
# Epoch 28/50
# 9/9 [==============================] - 2s 177ms/step - loss: 0.6079 - accuracy: 0.6716 - val_loss: 0.7140 - val_accuracy: 0.6176
# ResNet model for class floor trained and saved.
# Training ResNet model for class: cabinet
# Epoch 1/50
# 6/6 [==============================] - 12s 2s/step - loss: 3.8136 - accuracy: 0.5385 - val_loss: 0.9710 - val_accuracy: 0.5652
# Epoch 2/50
# 6/6 [==============================] - 5s 989ms/step - loss: 1.1899 - accuracy: 0.4945 - val_loss: 0.8690 - val_accuracy: 0.4348
# Epoch 3/50
# 6/6 [==============================] - 1s 133ms/step - loss: 1.1085 - accuracy: 0.5934 - val_loss: 1.0128 - val_accuracy: 0.4348
# Epoch 4/50
# 6/6 [==============================] - 5s 991ms/step - loss: 0.8523 - accuracy: 0.4725 - val_loss: 0.6881 - val_accuracy: 0.4348
# Epoch 5/50
# 6/6 [==============================] - 1s 136ms/step - loss: 0.6996 - accuracy: 0.5604 - val_loss: 0.7366 - val_accuracy: 0.4348
# Epoch 6/50
# 6/6 [==============================] - 4s 724ms/step - loss: 0.7078 - accuracy: 0.5165 - val_loss: 0.6548 - val_accuracy: 0.6087
# Epoch 7/50
# 6/6 [==============================] - 1s 146ms/step - loss: 0.6894 - accuracy: 0.5055 - val_loss: 0.7197 - val_accuracy: 0.4348
# Epoch 8/50
# 6/6 [==============================] - 1s 137ms/step - loss: 0.6910 - accuracy: 0.5604 - val_loss: 0.7504 - val_accuracy: 0.4348
# Epoch 9/50
# 6/6 [==============================] - 1s 133ms/step - loss: 0.6960 - accuracy: 0.5604 - val_loss: 0.7076 - val_accuracy: 0.4348
# Epoch 10/50
# 6/6 [==============================] - 1s 131ms/step - loss: 0.6849 - accuracy: 0.6154 - val_loss: 0.6958 - val_accuracy: 0.4348
# Epoch 11/50
# 6/6 [==============================] - 1s 131ms/step - loss: 0.6851 - accuracy: 0.5824 - val_loss: 0.6938 - val_accuracy: 0.4348
# Epoch 12/50
# 6/6 [==============================] - 1s 132ms/step - loss: 0.6769 - accuracy: 0.5824 - val_loss: 0.7091 - val_accuracy: 0.4348
# Epoch 13/50
# 6/6 [==============================] - 1s 133ms/step - loss: 0.6832 - accuracy: 0.5495 - val_loss: 0.6765 - val_accuracy: 0.4348
# Epoch 14/50
# 6/6 [==============================] - 11s 2s/step - loss: 0.6748 - accuracy: 0.5824 - val_loss: 0.6418 - val_accuracy: 0.8696
# Epoch 15/50
# 6/6 [==============================] - 1s 138ms/step - loss: 0.6640 - accuracy: 0.5495 - val_loss: 0.6669 - val_accuracy: 0.4348
# Epoch 16/50
# 6/6 [==============================] - 1s 133ms/step - loss: 1.1989 - accuracy: 0.5275 - val_loss: 0.6609 - val_accuracy: 0.6087
# Epoch 17/50
# 6/6 [==============================] - 3s 669ms/step - loss: 0.7300 - accuracy: 0.5714 - val_loss: 0.5653 - val_accuracy: 0.6522
# Epoch 18/50
# 6/6 [==============================] - 1s 139ms/step - loss: 0.7069 - accuracy: 0.6154 - val_loss: 0.6462 - val_accuracy: 0.7826
# Epoch 19/50
# 6/6 [==============================] - 1s 130ms/step - loss: 0.7502 - accuracy: 0.5495 - val_loss: 0.6376 - val_accuracy: 0.6087
# Epoch 20/50
# 6/6 [==============================] - 1s 133ms/step - loss: 0.7472 - accuracy: 0.5165 - val_loss: 0.6741 - val_accuracy: 0.4348
# Epoch 21/50
# 6/6 [==============================] - 1s 136ms/step - loss: 0.7255 - accuracy: 0.4945 - val_loss: 0.6872 - val_accuracy: 0.4348
# Epoch 22/50
# 6/6 [==============================] - 1s 138ms/step - loss: 0.6969 - accuracy: 0.5604 - val_loss: 0.7355 - val_accuracy: 0.4348
# Epoch 23/50
# 6/6 [==============================] - 1s 137ms/step - loss: 0.9487 - accuracy: 0.6374 - val_loss: 0.6263 - val_accuracy: 0.5652
# Epoch 24/50
# 6/6 [==============================] - 1s 139ms/step - loss: 0.7343 - accuracy: 0.4505 - val_loss: 0.7097 - val_accuracy: 0.4348
# Epoch 25/50
# 6/6 [==============================] - 1s 137ms/step - loss: 0.7150 - accuracy: 0.4725 - val_loss: 0.7395 - val_accuracy: 0.4348
# Epoch 26/50
# 6/6 [==============================] - 1s 135ms/step - loss: 0.7105 - accuracy: 0.5055 - val_loss: 0.6927 - val_accuracy: 0.4348
# Epoch 27/50
# 6/6 [==============================] - 1s 137ms/step - loss: 0.6845 - accuracy: 0.5385 - val_loss: 0.7195 - val_accuracy: 0.4348
# Epoch 28/50
# 6/6 [==============================] - 1s 135ms/step - loss: 0.6796 - accuracy: 0.5495 - val_loss: 0.6670 - val_accuracy: 0.4348
# Epoch 29/50
# 6/6 [==============================] - 1s 137ms/step - loss: 0.6636 - accuracy: 0.6044 - val_loss: 0.6414 - val_accuracy: 0.6087
# Epoch 30/50
# 6/6 [==============================] - 1s 136ms/step - loss: 0.6550 - accuracy: 0.6154 - val_loss: 0.6417 - val_accuracy: 0.6522
# Epoch 31/50
# 6/6 [==============================] - 1s 137ms/step - loss: 0.6808 - accuracy: 0.6044 - val_loss: 0.6509 - val_accuracy: 0.5217
# Epoch 32/50
# 6/6 [==============================] - 1s 193ms/step - loss: 0.7140 - accuracy: 0.5934 - val_loss: 0.7026 - val_accuracy: 0.4348
# ResNet model for class cabinet trained and saved.
# Training ResNet model for class: shower
# Epoch 1/50
# 11/11 [==============================] - 13s 907ms/step - loss: 1.2088 - accuracy: 0.5432 - val_loss: 1.2741 - val_accuracy: 0.5854
# Epoch 2/50
# 11/11 [==============================] - 7s 732ms/step - loss: 0.7959 - accuracy: 0.5000 - val_loss: 0.8035 - val_accuracy: 0.4146
# Epoch 3/50
# 11/11 [==============================] - 5s 476ms/step - loss: 0.7897 - accuracy: 0.4938 - val_loss: 0.6801 - val_accuracy: 0.5854
# Epoch 4/50
# 11/11 [==============================] - 8s 792ms/step - loss: 0.7179 - accuracy: 0.5000 - val_loss: 0.6771 - val_accuracy: 0.5854
# Epoch 5/50
# 11/11 [==============================] - 2s 135ms/step - loss: 0.7017 - accuracy: 0.5617 - val_loss: 0.6844 - val_accuracy: 0.5854
# Epoch 6/50
# 11/11 [==============================] - 1s 124ms/step - loss: 0.7245 - accuracy: 0.5062 - val_loss: 0.7246 - val_accuracy: 0.5854
# Epoch 7/50
# 11/11 [==============================] - 1s 130ms/step - loss: 0.7054 - accuracy: 0.5556 - val_loss: 0.6797 - val_accuracy: 0.5854
# Epoch 8/50
# 11/11 [==============================] - 1s 132ms/step - loss: 0.7423 - accuracy: 0.5432 - val_loss: 0.7523 - val_accuracy: 0.4146
# Epoch 9/50
# 11/11 [==============================] - 1s 127ms/step - loss: 0.7209 - accuracy: 0.4691 - val_loss: 0.6778 - val_accuracy: 0.5854
# Epoch 10/50
# 11/11 [==============================] - 4s 416ms/step - loss: 0.6801 - accuracy: 0.5802 - val_loss: 0.6767 - val_accuracy: 0.5854
# Epoch 11/50
# 11/11 [==============================] - 5s 509ms/step - loss: 0.6757 - accuracy: 0.5802 - val_loss: 0.6747 - val_accuracy: 0.5854
# Epoch 12/50
# 11/11 [==============================] - 1s 132ms/step - loss: 0.7123 - accuracy: 0.4568 - val_loss: 0.6815 - val_accuracy: 0.5854
# Epoch 13/50
# 11/11 [==============================] - 1s 124ms/step - loss: 0.6910 - accuracy: 0.5000 - val_loss: 0.6784 - val_accuracy: 0.5854
# Epoch 14/50
# 11/11 [==============================] - 1s 129ms/step - loss: 0.6855 - accuracy: 0.5802 - val_loss: 0.6787 - val_accuracy: 0.5854
# Epoch 15/50
# 11/11 [==============================] - 1s 129ms/step - loss: 0.6909 - accuracy: 0.5679 - val_loss: 0.6793 - val_accuracy: 0.5854
# Epoch 16/50
# 11/11 [==============================] - 1s 126ms/step - loss: 0.7197 - accuracy: 0.4753 - val_loss: 1.0486 - val_accuracy: 0.5854
# Epoch 17/50
# 11/11 [==============================] - 1s 132ms/step - loss: 0.7489 - accuracy: 0.5802 - val_loss: 0.6807 - val_accuracy: 0.5854
# Epoch 18/50
# 11/11 [==============================] - 1s 133ms/step - loss: 0.7391 - accuracy: 0.4568 - val_loss: 0.6803 - val_accuracy: 0.5854
# Epoch 19/50
# 11/11 [==============================] - 1s 134ms/step - loss: 0.6995 - accuracy: 0.4938 - val_loss: 0.6853 - val_accuracy: 0.5854
# Epoch 20/50
# 11/11 [==============================] - 1s 130ms/step - loss: 0.7098 - accuracy: 0.5802 - val_loss: 0.6790 - val_accuracy: 0.5854
# Epoch 21/50
# 11/11 [==============================] - 1s 124ms/step - loss: 0.6995 - accuracy: 0.5432 - val_loss: 0.6850 - val_accuracy: 0.5854
# Epoch 22/50
# 11/11 [==============================] - 1s 133ms/step - loss: 0.7355 - accuracy: 0.5123 - val_loss: 0.6861 - val_accuracy: 0.5854
# Epoch 23/50
# 11/11 [==============================] - 1s 129ms/step - loss: 0.7161 - accuracy: 0.5062 - val_loss: 6.5087 - val_accuracy: 0.4146
# Epoch 24/50
# 11/11 [==============================] - 1s 125ms/step - loss: 1.1973 - accuracy: 0.5432 - val_loss: 0.6986 - val_accuracy: 0.4146
# Epoch 25/50
# 11/11 [==============================] - 1s 131ms/step - loss: 0.8435 - accuracy: 0.4383 - val_loss: 0.7715 - val_accuracy: 0.5854
# Epoch 26/50
# 11/11 [==============================] - 2s 150ms/step - loss: 0.8364 - accuracy: 0.5679 - val_loss: 0.7255 - val_accuracy: 0.4146
# ResNet model for class shower trained and saved.
# Training ResNet model for class: tiles
# Epoch 1/50
# 23/23 [==============================] - 15s 480ms/step - loss: 1.3591 - accuracy: 0.5304 - val_loss: 0.7368 - val_accuracy: 0.4835
# Epoch 2/50
# 23/23 [==============================] - 6s 270ms/step - loss: 0.7232 - accuracy: 0.5028 - val_loss: 0.6886 - val_accuracy: 0.5714
# Epoch 3/50
# 23/23 [==============================] - 3s 130ms/step - loss: 0.6946 - accuracy: 0.5552 - val_loss: 0.7319 - val_accuracy: 0.4835
# Epoch 4/50
# 23/23 [==============================] - 3s 130ms/step - loss: 0.7153 - accuracy: 0.5331 - val_loss: 0.7040 - val_accuracy: 0.4835
# Epoch 5/50
# 23/23 [==============================] - 3s 132ms/step - loss: 0.6964 - accuracy: 0.5083 - val_loss: 0.6980 - val_accuracy: 0.4835
# Epoch 6/50
# 23/23 [==============================] - 3s 138ms/step - loss: 0.7406 - accuracy: 0.5359 - val_loss: 0.7558 - val_accuracy: 0.4835
# Epoch 7/50
# 23/23 [==============================] - 3s 133ms/step - loss: 0.6992 - accuracy: 0.5387 - val_loss: 0.6988 - val_accuracy: 0.4835
# Epoch 8/50
# 23/23 [==============================] - 3s 135ms/step - loss: 0.6948 - accuracy: 0.5525 - val_loss: 0.6928 - val_accuracy: 0.5165
# Epoch 9/50
# 23/23 [==============================] - 3s 136ms/step - loss: 0.7079 - accuracy: 0.5083 - val_loss: 0.7021 - val_accuracy: 0.4835
# Epoch 10/50
# 23/23 [==============================] - 3s 137ms/step - loss: 0.6876 - accuracy: 0.5608 - val_loss: 0.7267 - val_accuracy: 0.4835
# Epoch 11/50
# 23/23 [==============================] - 3s 138ms/step - loss: 0.6879 - accuracy: 0.5635 - val_loss: 0.6981 - val_accuracy: 0.4835
# Epoch 12/50
# 23/23 [==============================] - 3s 132ms/step - loss: 0.6865 - accuracy: 0.5663 - val_loss: 0.6950 - val_accuracy: 0.4835
# Epoch 13/50
# 23/23 [==============================] - 3s 137ms/step - loss: 0.6848 - accuracy: 0.5525 - val_loss: 0.6997 - val_accuracy: 0.4835
# Epoch 14/50
# 23/23 [==============================] - 3s 132ms/step - loss: 0.6857 - accuracy: 0.5580 - val_loss: 0.7046 - val_accuracy: 0.4835
# Epoch 15/50
# 23/23 [==============================] - 3s 140ms/step - loss: 0.6847 - accuracy: 0.5635 - val_loss: 0.7336 - val_accuracy: 0.4835
# Epoch 16/50
# 23/23 [==============================] - 3s 130ms/step - loss: 0.6896 - accuracy: 0.5552 - val_loss: 0.6969 - val_accuracy: 0.4835
# Epoch 17/50
# 23/23 [==============================] - 3s 147ms/step - loss: 0.6783 - accuracy: 0.5746 - val_loss: 0.7660 - val_accuracy: 0.4945
# ResNet model for class tiles trained and saved.

# %%
# Fundamental classes
import numpy as np
import pandas as pd
import tensorflow as tf
import os

# Image related
import cv2
from PIL import Image

#Performance Plot
from sklearn import metrics
from sklearn.metrics import f1_score, accuracy_score,confusion_matrix,classification_report
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# For the model and it's training
from sklearn.model_selection import train_test_split
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.models import Sequential, load_model, Model
from tensorflow.keras.layers import Conv2D, MaxPool2D, Dense, Flatten, Dropout, BatchNormalization, Input, Add
from tensorflow.keras.preprocessing.image import load_img, img_to_array

# Time
import time
import datetime

# Ultralytics
import ultralytics
ultralytics.checks()

from ultralytics import YOLO

from IPython.display import display, Image
import torch
from ultralytics import YOLO

# Mounting drive
from google.colab import drive
drive.mount('/content/drive')

# %%
def inicialitzacio():
  # Room Classification Model
  room_classification_model = YOLO('/content/drive/MyDrive/TFG/yolo-room-classification/training/train/weights/last.pt')

  # Obj segmentation models

  rooms = ['bathroom', 'kitchen', 'inside']

  dicc_obj_seg_models = {}

  for room in rooms:

    dicc_obj_seg_models[room] = YOLO(f'/content/drive/MyDrive/TFG/{room}-obj-seg/training-results-yolo/train01/weights/last.pt')

  # Obj classification models

  rooms = ['bathroom', 'kitchen', 'inside']
  classes = ['sink', 'floor', 'cabinet', 'counter', 'tiles']
  models = ['resnet', 'simple_cnn', 'vgg']

  dicc_obj_class_models = {}

  for room in rooms:

    models_class = {}

    for mod in models:
      dic = {}

      for classe in classes:
        dic[classe] = load_model(f'/content/drive/MyDrive/TFG/{room}-obj-classification/models/{mod}_model_{classe}.h5')

      models_class[mod] = dic

    dicc_obj_class_models[room] = models_class


  return room_classification_model, dicc_obj_seg_models, dicc_obj_class_models

# %%
IMG_PATH = '/content/drive/MyDrive/TFG/algorithm/prova_001.png'

room_classification_model, dicc_obj_seg_models, dicc_obj_class_models = inicialitzacio()
